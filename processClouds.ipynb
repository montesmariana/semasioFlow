# %% [markdown]
# # From distances to clouds
#
# The R half of the workflow takes care of the distance matrices and generates the rest of the files that we need for the visualization itself:
#
# - The coordinates to plot the tokens and context words
# - The distances between models
# - The coordinates to plot the models
# - Selection of medoids
# - HDBSCAN clustering

# %% [markdown]
# **note:**
#
# I tested everything on the original code as an R script, but only some things with the code as an R package. If anything doesn't work, please let me know (with an [issue](https://github.com/montesmariana/semcloud/issues/new/choose) or by mail).

# %%
devtools::install_github("montesmariana/semcloud")
# Out:
# Downloading GitHub repo montesmariana/semcloud@HEAD
# ✔  checking for file ‘/tmp/Rtmpfmf2I0/remotesb76855e1c276/montesmariana-semcloud-40a6188/DESCRIPTION’
# ─  preparing ‘semcloud’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘semcloud_0.0.0.9000.tar.gz’
# Installing package into ‘/home/mariana/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
library(semcloud)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
input_dir <- "../output/tokens" # where the data is stored
cw_dir <- "../output/cws"
output_dir <- "../github/" # where the data will go

# %% [markdown]
# ## Token coordinates
#
# In order to compute the token coordinates, we first need to decide which solutions we are going to choose,
# that is, whether we are going to run nMDS and, in the case we run t-SNE, which perplexities we are interested in.
# We might even want to run UMAP (not available yet in this code).
#
# While in the end I mostly looked at t-SNE with perplexity of 30, I will show the instructions when having more options.

# %%
# This list works for a loop in the function below and should then be stored as a json file
# in the github directory of each lemma, to tell the visualization what is being used
solutions_old <- list("mds" = ".mds")
for (perp in c(10, 20, 30, 50)) {
    solutions_old[[paste0("tsne", perp)]] = paste0(".tsne.", perp)
}
solutions_old
# Out:
# $mds
# [1] ".mds"
#
# $tsne10
# [1] ".tsne.10"
#
# $tsne20
# [1] ".tsne.20"
#
# $tsne30
# [1] ".tsne.30"
#
# $tsne50
# [1] ".tsne.50"

# %%
# For show at least, we will only use t-SNE 30, but the same should be done anyways
solutions <- list("tsne30" = ".tsne.30")

# %%
lemma <- "destroy" # your lemma
suffix <- ".ttmx.dist.pac"
models_file <- file.path(output_dir, lemma, paste0(lemma, '.models.tsv'))
files_list <- paste0(read_tsv(models_file, col_types = cols())$`_model`, suffix)
write(rjson::toJSON(solutions), file.path(output_dir, lemma, paste0(lemma, ".solutions.json")))
file.exists(file.path(input_dir, lemma, files_list[1]))
# Out:
# [1] TRUE

# %% [markdown]
# The `semcloud::getClouds()` function groups the full "workflow":
# 1. It sets up one empty dataframe per item in solution, which will be stored in a `[lemma].[solution].tsv` file.
#
# 2. For each file in `files_list`:
#
#     2.1 It extracts the model name
#
#     2.2 It loads the file with `semcloud::tokensFromPac()`
#
#     2.3 If `logrank = TRUE` (the default), it applies the transformation
#
#     2.4 It applies the corresponding algorithm and extracts the coordinates
#
#     2.5 It appends the coordinates as columns preceded by the name of the model to the corresponding dataframe
#
# In addition, if "mds" is one of the algorithms, it will *return* a list with the stress values.

# %%
getClouds(file.path(input_dir, lemma), file.path(output_dir, lemma),
          files_list, lemma, solutions)
# Out:
#   |======================================================================| 100%
# list()

# %%
read_tsv(file.path(output_dir, lemma, paste0(lemma, ".tsne.30.tsv")),
        col_types = cols())
# Out:
#     _id
# 1   verniel/verb/volkskrant_19990517_122/16
# 2   verniel/verb/het_nieuwsblad_20030830_01_369/154
# 3   verniel/verb/parool_20040309_16/329
# 4   verniel/verb/het_laatste_nieuws_20000306_01_201/52
# 5   verniel/verb/het_laatste_nieuws_20041112_01_230/104
# 6   verniel/verb/het_laatste_nieuws_20001219_01_282/59
# 7   verniel/verb/parool_20010412_58/69
# 8   verniel/verb/het_nieuwsblad_20031105_01_340/198
# 9   verniel/verb/parool_20001229_14/17
# 10  verniel/verb/het_laatste_nieuws_20040320_01_388/70
# 11  verniel/verb/algemeen_dagblad_20000325_147/15
# 12  verniel/verb/het_laatste_nieuws_20020102_01_119/67
# 13  verniel/verb/nrc_handelsblad_20000405_153/853
# 14  verniel/verb/het_laatste_nieuws_20001127_01_571/210
# 15  verniel/verb/het_laatste_nieuws_20041213_01_32/34
# 16  verniel/verb/parool_20030912_51/170
# 17  verniel/verb/algemeen_dagblad_20000405_72/99
# 18  verniel/verb/algemeen_dagblad_20000508_82/42
# 19  verniel/verb/nrc_handelsblad_20000609_11/74
# 20  verniel/verb/volkskrant_20000605_3/211
# 21  verniel/verb/het_laatste_nieuws_20030319_01_245/53
# 22  verniel/verb/de_morgen_20041211_01_99/79
# 23  verniel/verb/het_nieuwsblad_20000626_01_118/176
# 24  verniel/verb/het_nieuwsblad_20020518_01_498/173
# 25  verniel/verb/het_nieuwsblad_20030927_01_817/15
# 26  verniel/verb/het_nieuwsblad_20000407_01_292/10
# 27  verniel/verb/parool_20030614_107/376
# 28  verniel/verb/het_nieuwsblad_19990324_01_465/64
# 29  verniel/verb/het_laatste_nieuws_20000413_01_136/178
# 30  verniel/verb/het_nieuwsblad_20040719_01_246/133
# ⋮   ⋮
# 457 vernietig/verb/de_morgen_20010316_01_155/130
# 458 vernietig/verb/het_nieuwsblad_20020525_01_553/10
# 459 vernietig/verb/parool_20011030_47/64
# 460 vernietig/verb/algemeen_dagblad_20010323_152/41
# 461 vernietig/verb/het_nieuwsblad_20021102_01_538/141
# 462 vernietig/verb/de_morgen_20030203_01_45/461
# 463 vernietig/verb/de_morgen_20030918_01_51/90
# 464 vernietig/verb/nrc_handelsblad_20011222_29/21
# 465 vernietig/verb/nrc_handelsblad_20020921_19/198
# 466 vernietig/verb/volkskrant_20010413_123/73
# 467 vernietig/verb/volkskrant_19991210_14/119
# 468 vernietig/verb/de_standaard_20030520_01_6/386
# 469 vernietig/verb/algemeen_dagblad_20001201_49/300
# 470 vernietig/verb/de_standaard_20030212_01_20/128
# 471 vernietig/verb/parool_20010222_30/60
# 472 vernietig/verb/de_standaard_20010407_01_128/162
# 473 vernietig/verb/volkskrant_20000928_64/91
# 474 vernietig/verb/nrc_handelsblad_20000126_94/317
# 475 vernietig/verb/het_laatste_nieuws_19990622_01_341/140
# 476 vernietig/verb/algemeen_dagblad_20040228_03/33
# 477 vernietig/verb/volkskrant_19990113_29/54
# 478 vernietig/verb/de_standaard_20040807_01_89/32
# 479 vernietig/verb/het_nieuwsblad_20020508_01_298/29
# 480 verniel/verb/het_laatste_nieuws_20031028_01_295/10
# 481 verniel/verb/volkskrant_20010116_48/18
# 482 verniel/verb/het_laatste_nieuws_20041210_01_387/54
# 483 verniel/verb/het_nieuwsblad_20030304_01_77/10
# 484 vernietig/verb/de_standaard_20030703_01_20/165
# 485 vernietig/verb/de_standaard_20030416_01_129/251
# 486 vernietig/verb/algemeen_dagblad_20011026_70/36
#     destroy.nobound5-5lex.PPMIweight.LENGTHFOC.SOCPOSnav.x
# 1     4.5103586
# 2    19.3327374
# 3     6.4711766
# 4    10.3221772
# 5     5.8366891
# 6    20.0071655
# 7     3.4781955
# 8    11.8003622
# 9    19.8900194
# 10   -4.7441414
# 11    6.0377791
# 12   15.1046239
# 13  -14.7099334
# 14   -3.7876055
# 15   -0.8252712
# 16    3.9875870
# 17   -1.1938335
# 18   -2.7709968
# 19   -7.5712194
# 20   10.4002752
# 21    5.2830737
# 22   -3.3119423
# 23    2.3966340
# 24   10.6067344
# 25    3.2241174
# 26    0.6747841
# 27   -1.1564253
# 28   -5.1052861
# 29   -8.2455191
# 30   -0.9236387
# ⋮   ⋮
# 457 -10.947845
# 458  22.738208
# 459 -12.533114
# 460  15.271270
# 461 -12.587785
# 462  -9.025338
# 463 -17.635058
# 464 -12.361383
# 465   2.467954
# 466   4.296354
# 467   1.811944
# 468 -10.776461
# 469  12.379044
# 470  -9.727660
# 471  -6.992121
# 472  -8.283523
# 473  -4.646879
# 474  -8.138406
# 475  11.979819
# 476  -1.267039
# 477  -8.533696
# 478  -5.255060
# 479  14.902662
# 480   0.000000
# 481   0.000000
# 482   0.000000
# 483   0.000000
# 484   0.000000
# 485   0.000000
# 486   0.000000
#     destroy.nobound5-5lex.PPMIweight.LENGTHFOC.SOCPOSnav.y
# 1   -13.563040
# 2   -31.172588
# 3    10.039919
# 4   -26.462641
# 5    11.836600
# 6   -29.411883
# 7    17.484237
# 8   -37.140226
# 9   -32.695587
# 10  -34.932504
# 11   12.730238
# 12  -35.047150
# 13   17.153207
# 14  -28.306703
# 15  -36.975469
# 16   12.470709
# 17  -10.828886
# 18  -19.656661
# 19  -32.006267
# 20  -27.894397
# 21   17.332252
# 22  -23.854781
# 23  -32.679044
# 24  -28.981441
# 25  -13.139595
# 26  -35.524551
# 27   -6.510223
# 28  -27.465576
# 29  -31.183621
# 30  -25.225997
# ⋮   ⋮
# 457  30.89541402
# 458 -31.92574721
# 459  21.41407152
# 460   0.88929946
# 461  -1.78702438
# 462   0.68352675
# 463   0.82033838
# 464   1.76550439
# 465 -16.00916060
# 466  18.26496395
# 467  18.71662257
# 468   5.36553119
# 469  -2.80891309
# 470   0.57373176
# 471  45.05001767
# 472  40.33846718
# 473 -18.48366419
# 474  19.01580420
# 475   0.08850955
# 476 -30.08563675
# 477   5.89315065
# 478  33.36708541
# 479   0.18879159
# 480   0.00000000
# 481   0.00000000
# 482   0.00000000
# 483   0.00000000
# 484   0.00000000
# 485   0.00000000
# 486   0.00000000
#     destroy.nobound5-5lex.PPMIweight.LENGTHFOC.SOCPOSall.x
# 1   15.523726
# 2   13.140263
# 3    1.285111
# 4   12.980446
# 5   -2.426130
# 6   14.631492
# 7   -7.816589
# 8    6.336671
# 9   15.296789
# 10  32.936057
# 11  -3.274974
# 12  26.936576
# 13  -9.354563
# 14  27.414108
# 15  35.350631
# 16  -6.212178
# 17  11.851796
# 18  17.855502
# 19  27.581481
# 20  11.401530
# 21  -6.077262
# 22  25.048261
# 23  33.349446
# 24  14.356387
# 25  14.887542
# 26  36.865788
# 27   6.495610
# 28  30.220775
# 29  25.996155
# 30  28.077419
# ⋮   ⋮
# 457 -20.614465
# 458  13.880070
# 459 -24.462730
# 460  -7.523097
# 461  13.554776
# 462   3.526002
# 463   8.514648
# 464  10.585709
# 465  17.993576
# 466  -7.785212
# 467  -9.849487
# 468   2.264734
# 469  -3.975962
# 470   4.641931
# 471 -38.210222
# 472 -41.921690
# 473  25.883286
# 474 -15.739101
# 475  -4.346646
# 476  33.621786
# 477   5.435772
# 478 -32.616205
# 479  -6.886387
# 480   0.000000
# 481   0.000000
# 482   0.000000
# 483   0.000000
# 484   0.000000
# 485   0.000000
# 486   0.000000
#     destroy.nobound5-5lex.PPMIweight.LENGTHFOC.SOCPOSall.y
# 1    -5.57195978
# 2   -25.33798017
# 3     0.07739147
# 4   -15.97108131
# 5     0.70845915
# 6   -30.99748811
# 7     0.90975546
# 8   -24.03425472
# 9   -26.00720552
# 10  -18.12818766
# 11    0.53228252
# 12  -21.11084586
# 13  -13.23320300
# 14  -11.77590663
# 15  -17.98280043
# 16    5.17855743
# 17   -1.85810822
# 18   -3.83492087
# 19  -17.99602798
# 20  -16.05772766
# 21    2.45726787
# 22   -8.11503927
# 23  -12.75431319
# 24  -17.51695642
# 25   -3.73872528
# 26  -15.48945154
# 27    0.37249482
# 28  -13.16543692
# 29  -17.64177199
# 30   -8.07984036
# ⋮   ⋮
# 457   4.0215565
# 458 -28.9450739
# 459  19.6303477
# 460  29.0996660
# 461  14.6383715
# 462  13.8759083
# 463  17.6226931
# 464  12.3182812
# 465  -1.2396663
# 466  -0.4412044
# 467   4.2695622
# 468   8.8481925
# 469  28.8474519
# 470  13.8090981
# 471  18.9592907
# 472   9.9779132
# 473  -3.5198398
# 474  -7.5493172
# 475  25.7421735
# 476  -9.1590218
# 477   8.0205935
# 478  16.7741987
# 479  29.1810113
# 480   0.0000000
# 481   0.0000000
# 482   0.0000000
# 483   0.0000000
# 484   0.0000000
# 485   0.0000000
# 486   0.0000000
#     destroy.nobound5-5lex.PPMIweight.LENGTH5000.SOCPOSnav.x
# 1   -2.1339912
# 2   20.9769407
# 3    2.3022332
# 4    5.6491243
# 5    3.0882856
# 6   19.1906157
# 7    1.8247112
# 8   31.2143513
# 9   23.4260454
# 10  10.1041535
# 11   3.5169553
# 12  18.9737991
# 13  13.4513877
# 14   1.6115229
# 15   8.6580402
# 16   2.8830060
# 17  11.7489569
# 18  15.1800488
# 19  12.3182973
# 20  19.0508110
# 21  -1.2107466
# 22   2.8198547
# 23   5.8755483
# 24  18.5847117
# 25  -2.8614100
# 26   9.4491062
# 27   3.6457898
# 28   5.7816444
# 29  11.9808592
# 30  -0.2826797
# ⋮   ⋮
# 457  -2.48023264
# 458  26.41483003
# 459 -23.36666567
# 460 -17.36412335
# 461   0.24554286
# 462 -10.50576885
# 463 -30.32037149
# 464 -24.94510853
# 465 -20.19132723
# 466  -0.00672405
# 467  -0.44853789
# 468  -2.37378754
# 469 -14.52376997
# 470 -10.10429125
# 471   4.57085156
# 472   4.80669621
# 473 -13.02013811
# 474 -14.28114938
# 475 -11.93722729
# 476   7.98416702
# 477 -23.57110076
# 478 -21.21759238
# 479 -17.38237265
# 480   0.00000000
# 481   0.00000000
# 482   0.00000000
# 483   0.00000000
# 484   0.00000000
# 485   0.00000000
# 486   0.00000000
#     destroy.nobound5-5lex.PPMIweight.LENGTH5000.SOCPOSnav.y
# 1     8.45883375
# 2    31.89025556
# 3    14.24235263
# 4    19.77761667
# 5    -4.20312327
# 6    24.41962093
# 7   -11.95862438
# 8    26.73777482
# 9    34.98021575
# 10   25.99584947
# 11   -6.28905871
# 12   23.78063297
# 13    8.89538633
# 14   23.24600936
# 15   32.99371481
# 16   -5.41959044
# 17   14.85934183
# 18   -4.88195404
# 19   22.70414365
# 20   32.16273167
# 21   -9.17598540
# 22   19.79303019
# 23   34.53646222
# 24   35.02772833
# 25    8.80108691
# 26   31.76256658
# 27   -0.03231758
# 28   24.00894843
# 29   19.04220564
# 30   21.19125809
# ⋮   ⋮
# 457 -21.5651124
# 458  35.0628352
# 459 -17.0119821
# 460   3.7665477
# 461  -2.3388628
# 462 -21.6611860
# 463  -3.8484135
# 464   0.4356395
# 465 -12.4640406
# 466  -8.2237185
# 467 -15.1712353
# 468 -14.9444281
# 469   6.6920234
# 470 -23.4897986
# 471 -47.8418596
# 472 -43.5754389
# 473 -17.1014646
# 474 -12.2860942
# 475   3.8563096
# 476  26.6102305
# 477  -1.7830809
# 478 -20.9419045
# 479   3.9612550
# 480   0.0000000
# 481   0.0000000
# 482   0.0000000
# 483   0.0000000
# 484   0.0000000
# 485   0.0000000
# 486   0.0000000
#     destroy.nobound5-5lex.PPMIweight.LENGTH5000.SOCPOSall.x
# 1    -7.6833499
# 2    10.0587641
# 3     3.6930121
# 4     9.5433983
# 5     8.4971297
# 6    -6.2361716
# 7    10.8026153
# 8    14.5511306
# 9     6.8536828
# 10   -2.2243332
# 11    9.0405627
# 12   -6.2724356
# 13    9.0957152
# 14    3.0365560
# 15   -6.9588575
# 16    7.9759836
# 17   -5.6788266
# 18   -0.3388059
# 19   -6.0047387
# 20   12.4018604
# 21    8.6931327
# 22    1.7717269
# 23  -11.0499598
# 24   11.4933528
# 25   -9.1682295
# 26   -8.7232639
# 27    7.5092372
# 28   -1.6539098
# 29    9.0767471
# 30    4.6194998
# ⋮   ⋮
# 457   6.134080
# 458   7.289460
# 459  -6.557244
# 460  22.548930
# 461  12.709899
# 462   1.413415
# 463 -19.634925
# 464 -15.446434
# 465 -14.600531
# 466  11.767208
# 467   7.226430
# 468   2.162548
# 469  20.840890
# 470   3.404356
# 471 -18.572940
# 472 -15.303547
# 473  -1.342402
# 474  -9.736727
# 475  18.085535
# 476  -3.325614
# 477 -13.178878
# 478 -10.368716
# 479  22.673790
# 480   0.000000
# 481   0.000000
# 482   0.000000
# 483   0.000000
# 484   0.000000
# 485   0.000000
# 486   0.000000
#     destroy.nobound5-5lex.PPMIweight.LENGTH5000.SOCPOSall.y
# 1     5.813211
# 2    37.621520
# 3    11.971478
# 4    24.707643
# 5    -6.026609
# 6    21.303664
# 7   -14.610629
# 8    40.960605
# 9    40.043036
# 10   29.753445
# 11   -7.638096
# 12   20.741447
# 13    7.593666
# 14   22.333974
# 15   32.391366
# 16   -8.744151
# 17   10.015254
# 18   -2.611418
# 19   17.179250
# 20   37.300522
# 21  -10.217785
# 22   18.529587
# 23   30.585852
# 24   40.027996
# 25    6.094239
# 26   32.375958
# 27   -2.829566
# 28   24.638636
# 29   -3.135490
# 30   19.969152
# ⋮   ⋮
# 457 -18.1097714
# 458  36.3310643
# 459 -22.3105930
# 460   0.5946758
# 461  -3.3802861
# 462 -27.2721293
# 463  -4.8380157
# 464   2.3009960
# 465 -22.0661077
# 466 -12.9321735
# 467 -14.8483297
# 468 -16.6342538
# 469   6.8166516
# 470 -28.4092288
# 471 -41.8112103
# 472 -39.4428266
# 473 -29.1688997
# 474 -19.0488084
# 475   4.6106533
# 476  26.5582314
# 477   0.5038241
# 478 -27.0896335
# 479   0.6148370
# 480   0.0000000
# 481   0.0000000
# 482   0.0000000
# 483   0.0000000
# 484   0.0000000
# 485   0.0000000
# 486   0.0000000
#     destroy.nobound5-5lex.PPMIselection.LENGTHFOC.SOCPOSnav.x ⋯
# 1   -5.9074627                                                ⋯
# 2   21.6792727                                                ⋯
# 3    1.1009828                                                ⋯
# 4   15.1519018                                                ⋯
# 5    1.4728773                                                ⋯
# 6   16.4316494                                                ⋯
# 7   -2.9555374                                                ⋯
# 8   23.9330209                                                ⋯
# 9   20.5052605                                                ⋯
# 10   9.6420902                                                ⋯
# 11   1.3145174                                                ⋯
# 12   9.0761517                                                ⋯
# 13  10.7014587                                                ⋯
# 14   5.0503787                                                ⋯
# 15  14.1083399                                                ⋯
# 16   1.8163692                                                ⋯
# 17   0.1133253                                                ⋯
# 18   2.9347622                                                ⋯
# 19  -4.4038195                                                ⋯
# 20  20.4837449                                                ⋯
# 21   2.6647626                                                ⋯
# 22   2.6941338                                                ⋯
# 23  12.2007382                                                ⋯
# 24  19.1930430                                                ⋯
# 25   1.2399568                                                ⋯
# 26  11.8626762                                                ⋯
# 27  -8.6219518                                                ⋯
# 28   3.9398625                                                ⋯
# 29   1.7934089                                                ⋯
# 30   6.9456019                                                ⋯
# ⋮   ⋮                                                         ⋱
# 457  -5.803311                                                ⋯
# 458  22.170780                                                ⋯
# 459 -16.005135                                                ⋯
# 460 -19.317598                                                ⋯
# 461   8.913604                                                ⋯
# 462 -19.748099                                                ⋯
# 463 -14.792502                                                ⋯
# 464 -15.734071                                                ⋯
# 465  -2.156243                                                ⋯
# 466  -3.967882                                                ⋯
# 467  -7.431530                                                ⋯
# 468 -11.004210                                                ⋯
# 469 -15.466084                                                ⋯
# 470 -19.498099                                                ⋯
# 471  -2.584497                                                ⋯
# 472 -17.546984                                                ⋯
# 473  -2.986775                                                ⋯
# 474   1.453900                                                ⋯
# 475 -13.255595                                                ⋯
# 476   5.065573                                                ⋯
# 477 -11.820412                                                ⋯
# 478 -19.562396                                                ⋯
# 479 -18.849215                                                ⋯
# 480   0.000000                                                ⋯
# 481   0.000000                                                ⋯
# 482   0.000000                                                ⋯
# 483   0.000000                                                ⋯
# 484   0.000000                                                ⋯
# 485   0.000000                                                ⋯
# 486   0.000000                                                ⋯
#     destroy.LEMMAPATH2.PPMIselection.LENGTH5000.SOCPOSall.x
# 1    19.7423844
# 2    16.9336546
# 3    -2.8861642
# 4    12.2578615
# 5   -18.8165576
# 6    17.3541587
# 7   -20.9505372
# 8    16.0902389
# 9    13.3594413
# 10    5.6806095
# 11   11.2392994
# 12  -15.7150130
# 13    9.3495626
# 14   12.7052174
# 15    5.8731021
# 16  -24.6261652
# 17    1.7318353
# 18   16.7705093
# 19   22.1234711
# 20    9.1530845
# 21  -23.9616209
# 22   -9.0092319
# 23  -24.0258219
# 24    0.6114826
# 25   20.9570869
# 26    8.1697524
# 27  -26.3201660
# 28  -11.8364661
# 29  -21.2314031
# 30   -1.9603571
# ⋮   ⋮
# 457 -30.5604784
# 458   0.0000000
# 459  24.1714876
# 460  16.8183541
# 461  -0.9353708
# 462  -0.2473476
# 463   8.5318964
# 464  11.4299553
# 465  -0.2126269
# 466 -31.5643177
# 467 -20.7426444
# 468 -14.7872315
# 469  -8.8831034
# 470  -6.3468703
# 471  19.1658476
# 472   0.0000000
# 473   4.7349318
# 474   8.5354560
# 475 -13.2391563
# 476  13.0321863
# 477   7.4571185
# 478  -3.4610541
# 479 -21.3081606
# 480   6.5200647
# 481  20.5912911
# 482  15.9255264
# 483   6.6230665
# 484  -7.3534282
# 485   0.3295744
# 486  21.7346593
#     destroy.LEMMAPATH2.PPMIselection.LENGTH5000.SOCPOSall.y
# 1   13.6412159
# 2    9.6183536
# 3   19.4406992
# 4   18.1967712
# 5   18.0633348
# 6   18.3462981
# 7   19.1523026
# 8   15.3451155
# 9   17.6768266
# 10  17.8796340
# 11  19.2841464
# 12  21.2797676
# 13   8.4350324
# 14   4.9225862
# 15  17.8945977
# 16   9.6294394
# 17  -3.1272388
# 18   8.5784565
# 19  -5.8099113
# 20  18.9639503
# 21  22.2598810
# 22  24.3223526
# 23  17.6501395
# 24  -0.1472297
# 25  11.1298755
# 26  25.7444822
# 27  20.8340404
# 28  27.8006860
# 29  11.8919769
# 30   4.8947251
# ⋮   ⋮
# 457  10.961623
# 458   0.000000
# 459 -21.807831
# 460  -8.856282
# 461 -13.759315
# 462 -16.276582
# 463 -13.736291
# 464 -13.842347
# 465  -8.020474
# 466  14.804745
# 467  10.938302
# 468  18.992989
# 469 -26.217156
# 470 -27.292892
# 471  -9.747472
# 472   0.000000
# 473 -21.337065
# 474 -18.330644
# 475  19.610984
# 476   9.259992
# 477   2.233362
# 478 -30.559278
# 479  11.904626
# 480  25.739370
# 481  -4.050616
# 482  13.102093
# 483  26.651796
# 484 -31.704134
# 485  -1.965842
# 486 -20.827816
#     destroy.LEMMAPATH2.PPMIno.LENGTHFOC.SOCPOSnav.x
# 1    -4.465949
# 2    -9.304723
# 3   -23.369125
# 4   -16.753299
# 5   -11.947114
# 6   -23.546286
# 7   -16.936964
# 8   -22.534068
# 9   -15.933811
# 10  -28.965622
# 11  -15.394580
# 12  -11.678467
# 13  -14.099624
# 14  -29.457392
# 15  -28.338590
# 16    1.713100
# 17   16.031210
# 18   10.018540
# 19    8.074550
# 20  -14.521429
# 21  -20.254717
# 22  -22.862169
# 23   -7.933993
# 24    4.478992
# 25   -6.705430
# 26  -34.797810
# 27  -14.649294
# 28  -28.532027
# 29   -2.118733
# 30  -31.637716
# ⋮   ⋮
# 457   2.4793343
# 458   0.0000000
# 459  35.6243656
# 460   8.4747300
# 461  -6.1822223
# 462  14.5411367
# 463   0.9981767
# 464  -5.7889278
# 465   4.4936727
# 466  11.7232665
# 467  -0.2298984
# 468 -11.2560038
# 469  16.9566515
# 470  14.9157167
# 471  12.2012158
# 472   0.0000000
# 473   7.5202667
# 474   0.4766188
# 475 -13.3444541
# 476 -27.2267850
# 477 -10.5321451
# 478  18.9560307
# 479  -2.4878018
# 480 -34.2718718
# 481  11.3094232
# 482 -16.7438363
# 483 -34.6325476
# 484  20.6730961
# 485  16.5170589
# 486  32.0300969
#     destroy.LEMMAPATH2.PPMIno.LENGTHFOC.SOCPOSnav.y
# 1    15.0480808
# 2    14.3698826
# 3     3.3884856
# 4    22.4663665
# ...
# 7   -16.0238694
# 8   -26.9694092
# 9   -26.3309408
# 10  -15.6423908
# 11  -23.2406986
# 12   -3.4250047
# 13  -32.8834729
# 14   -5.2908692
# 15  -16.8959028
# 16    1.4776128
# 17   -0.9257537
# 18    8.3972778
# 19   21.6205384
# 20  -22.6515636
# 21  -36.4488261
# 22   -8.2170763
# 23   -0.2832632
# 24   -4.6125669
# 25  -21.6226891
# 26  -17.4155794
# 27  -11.2650986
# 28   -9.9002931
# 29    0.5659243
# 30   -6.7248528
# ⋮   ⋮
# 457   6.8023093
# 458   0.0000000
# 459  35.5912929
# 460  18.3062871
# 461  -0.5361195
# 462   8.4033969
# 463  14.0968610
# 464 -13.5684898
# 465  -5.2206886
# 466  24.9752308
# 467   0.6868158
# 468  -3.4652567
# 469   7.5983962
# 470   6.9179502
# 471  20.8773634
# 472   0.0000000
# 473   6.5719397
# 474  13.6663665
# 475  -6.6262298
# 476 -18.0918535
# 477  -6.1639110
# 478  10.5916159
# 479 -13.3825597
# 480 -17.6981534
# 481  19.2682443
# 482 -30.5564717
# 483 -18.5793110
# 484  12.5060988
# 485  -2.5304763
# 486  34.9075451
#     destroy.LEMMAPATH2.PPMIno.LENGTH5000.SOCPOSnav.x
# 1   -11.9683826
# 2   -15.3910805
# 3   -11.9056482
# 4   -19.1415944
# 5    -0.9243321
# 6   -24.6485177
# 7    11.9147595
# 8   -18.8347031
# 9   -16.0100635
# 10  -10.9341254
# 11  -16.7457716
# 12    1.4118266
# 13  -24.1626114
# 14   -5.7142324
# 15  -13.0925177
# 16    2.6226322
# 17    8.2309140
# 18    6.6794667
# 19   -3.4267873
# 20  -12.6369898
# 21    0.9488166
# 22   -6.4473786
# 23    2.9694313
# 24    6.2954958
# 25  -14.2572182
# 26  -18.1570492
# 27   10.9548050
# 28   -5.4021281
# 29    8.9314484
# 30    0.9319013
# ⋮   ⋮
# 457   6.4038957
# 458   0.0000000
# 459   0.0610255
# 460  -0.6314555
# 461   8.1668170
# 462   6.0087774
# 463   4.9937219
# 464  -9.0056375
# 465   8.4403211
# 466   0.6870273
# 467   9.2410840
# 468   0.7316160
# 469  26.8824820
# 470  21.3727728
# 471  -5.6005175
# 472   0.0000000
# 473   5.7205385
# 474   2.7070993
# 475  -0.1895799
# 476 -18.0791417
# 477   3.4418664
# 478  17.1689676
# 479   8.6242059
# 480 -18.8014786
# 481  -6.7475290
# 482 -17.5475871
# 483 -19.1460622
# 484  22.0641307
# 485   8.3193519
# 486  -4.4291714
#     destroy.LEMMAPATH2.PPMIno.LENGTH5000.SOCPOSnav.y
# 1     8.60219248
# 2     7.90511293
# 3   -19.02173945
# 4     2.17279014
# 5   -34.16728462
# 6     5.23275936
# 7   -30.06665159
# 8     0.19495360
# 9    -0.01796889
# 10   -1.68406376
# 11   -0.83099680
# 12  -24.49384982
# 13    7.39139575
# 14   -1.24966044
# 15   -1.60051903
# 16  -38.36657602
# 17   -4.94369082
# 18   14.57763645
# 19   14.79023358
# 20    5.47875683
# 21  -30.53868274
# 22  -22.42926802
# 23  -31.40045289
# 24   -2.09022517
# 25    4.22323932
# 26   -8.54491223
# 27  -30.70351357
# 28  -25.35688511
# 29  -24.73683038
# 30   -8.34806594
# ⋮   ⋮
# 457 -35.920175
# 458   0.000000
# 459  35.091737
# 460   9.773702
# 461  21.262519
# 462  10.660255
# 463  20.607747
# 464  11.051847
# 465  11.779620
# 466 -39.018349
# 467 -24.146480
# 468 -25.302052
# 469  22.184536
# 470  19.074581
# 471  14.813647
# 472   0.000000
# 473  16.196183
# 474  16.138006
# 475 -24.067618
# 476   9.617892
# 477   1.130261
# 478  24.267744
# 479 -25.251105
# 480  -9.123349
# 481  20.744940
# 482   6.379910
# 483  -8.381023
# 484  26.183569
# 485  -2.035858
# 486  29.262522
#     destroy.LEMMAPATH2.PPMIno.LENGTH5000.SOCPOSall.x
# 1    15.344079
# 2    11.678149
# 3     2.574085
# 4     8.096723
# 5   -21.654089
# 6     3.934130
# 7   -10.959444
# 8     7.597424
# 9    11.710458
# 10   12.157457
# 11   10.283182
# 12  -25.980397
# 13   -6.680519
# 14   15.762286
# 15    7.758534
# 16  -21.669052
# 17   -3.837614
# 18   11.904300
# 19   21.545269
# 20    5.545736
# 21  -29.235876
# 22  -13.618646
# 23  -26.583308
# 24   -4.788518
# 25   13.939999
# 26   12.072812
# 27  -12.128495
# 28  -32.889881
# 29  -20.778517
# 30   -7.223279
# ⋮   ⋮
# 457 -26.956217
# 458   0.000000
# 459  22.307015
# 460  19.587125
# 461  -2.277284
# 462   7.856295
# 463   9.767105
# 464  19.187819
# 465   8.410667
# 466 -29.043312
# 467 -20.615834
# 468 -23.976606
# 469  -3.694145
# 470  -1.791338
# 471  24.493150
# 472   0.000000
# 473  12.375207
# 474  12.918914
# 475 -23.269643
# 476   9.565015
# 477   1.686264
# 478   5.423094
# 479   1.673801
# 480  11.366432
# 481  23.305020
# 482   9.798937
# 483  11.160673
# 484   3.773897
# 485  -4.760577
# 486  22.689527
#     destroy.LEMMAPATH2.PPMIno.LENGTH5000.SOCPOSall.y
# 1   -14.2524173
# 2   -11.5082566
# 3   -28.4551199
# 4   -17.7693043
# 5     0.4275975
# 6   -17.0497189
# 7   -20.6475566
# 8   -21.2066294
# 9   -22.1443794
# 10  -15.4045734
# 11  -18.7187026
# 12  -12.3149093
# 13    5.4107868
# 14   -8.5337383
# 15  -25.0666890
# 16    2.7798049
# 17   -0.7814137
# 18    2.4709743
# 19   -8.6591050
# 20   -9.1133801
# 21   -7.7062458
# 22  -11.9394553
# 23   -4.2999336
# 24   -0.6139365
# 25  -20.7336125
# 26  -30.0820193
# 27  -20.0431289
# 28  -12.9829539
# 29   -4.5345252
# 30   -4.5887711
# ⋮   ⋮
# 457   2.5868427
# 458   0.0000000
# 459  19.8504840
# 460  -1.0698701
# 461  12.2411962
# 462   5.7867614
# 463  -3.0488652
# 464 -14.1563582
# 465   3.2775648
# 466   2.3018323
# 467  -5.1621934
# 468 -11.4214596
# 469  29.3552737
# 470  24.5004200
# 471  -5.1254845
# 472   0.0000000
# 473   4.5393431
# 474   8.1911510
# 475 -12.8335521
# 476 -10.9777721
# 477  -4.8864509
# 478  26.9932313
# 479 -29.3143005
# 480 -30.3317918
# 481  -3.4211069
# 482 -14.6051168
# 483 -29.1423499
# 484  30.6091842
# 485   0.9784182
# 486  15.2236636

# %%
# If we have a many lemmas, we could run this on a loop:
# suffix <- ".ttmx.dist.pac"
# for (lemma in lemmas) {
#     models_file <- file.path(output_dir, lemma, paste0(lemma, '.models.tsv'))
#     files_list <- paste0(read_tsv(models_file, col_types = cols())$`_model`, suffix)
#     write(rjson::toJSON(solutions), file.path(output_dir, lemma, paste0(lemma, ".solutions.json")))    
#     getClouds(file.path(input_dir, lemma), file.path(output_dir, lemma),
#           files_list, lemma, solutions)
# }

# %% [markdown]
# ## Context words coordinates
# For the context words, the workflow is exactly the same as for the tokens. The difference is that the files are saved as `.csv` (because for some reason R cannot read them when they are `.wwmx...` and so it uses the `focdistsFromCsv()` function.

# %%
suffix <- ".wwmx.dist.csv"
files_list <- paste0(read_tsv(models_file, col_types = cols())$`_model`, suffix)

getClouds(file.path(cw_dir, lemma), file.path(output_dir, lemma),
          files_list, lemma, solutions, type = "focdists")
# Out:
#   |======================================================================| 100%
# list()

# %%
# If we have a many lemmas, we could run this on a loop:
# suffix <- ".wwmx.dist.csv"
# for (lemma in lemmas) {
#     models_file <- file.path(output_dir, lemma, paste0(lemma, '.models.tsv'))
#     files_list <- paste0(read_tsv(models_file, col_types = cols())$`_model`, suffix)
#     getClouds(file.path(cw_dir, lemma), file.path(output_dir, lemma),
#           files_list, lemma, solutions)
# }

# %% [markdown]
# ## Model distances and coordinates
#
# The function belows loads the `[lemma].models.tsv` file in the `output_dir` in order to modify it by appending the coordinates from an nMDS on the distances between the models. By default, it will compute "euclidean" distances on the transformed matrices, but the function can be changed with the `fun` argument, and the transformation can be turned off with the `transformed` argument. It returns some data for a register (which I tend to combine across lemmas and store as `euclidean_register.tsv` to tell the index of the visualization which lemmas to offer :)
#
# Under the hood, it also stores the distance matrix as `[lemma].models.dist.tsv`. If the file already exists, it loads it instead of recomputing the distances.

# %%
reg <- compLemma(lemma, file.path(input_dir, lemma), file.path(output_dir, lemma))
# Out:
# Run 0 stress 0.2096644
# Run 1 stress 0.2128179
# Run 2 stress 0.2180829
# Run 3 stress 0.2324361
# Run 4 stress 0.216838
# Run 5 stress 0.215678
# Run 6 stress 0.2217743
# Run 7 stress 0.2360372
# Run 8 stress 0.2172706
# Run 9 stress 0.2155969
# Run 10 stress 0.2472629
# Run 11 stress 0.2128561
# Run 12 stress 0.2133979
# Run 13 stress 0.2168053
# Run 14 stress 0.2204092
# Run 15 stress 0.2418459
# Run 16 stress 0.2404527
# Run 17 stress 0.2138515
# Run 18 stress 0.2234314
# Run 19 stress 0.2141747
# Run 20 stress 0.2223146
# Run 21 stress 0.2563006
# Run 22 stress 0.2226901
# Run 23 stress 0.2174322
# Run 24 stress 0.2182067
# Run 25 stress 0.2377647
# Run 26 stress 0.2162604
# Run 27 stress 0.2151332
# Run 28 stress 0.2541734
# Run 29 stress 0.2427642
# Run 30 stress 0.2163842
# *** No convergence -- monoMDS stopping criteria:
#     16: stress ratio > sratmax
#     14: scale factor of the gradient < sfgrmin
# [1] 0.2096644
# Error in stats::setNames(., .data, c("_model", "model.x", "model.y")): unused argument (c("_model", "model.x", "model.y"))
# Traceback:
#
# 1. compLemma(lemma, file.path(input_dir, lemma), file.path(output_dir,
#  .     lemma))
# 2. dst.MDS$points %>% as.data.frame %>% tibble::rownames_to_column %>%
#  .     tibble::as_tibble %>% stats::setNames(.data, c("_model",
#  .     "model.x", "model.y")) %>% dplyr::left_join(models, by = "_model")
# 3. dplyr::left_join(., models, by = "_model")

# %%
reg # other information could be added eventually, like range of number of tokens, or part-of-speech
# Out:
#   type    models stress date
# 1 destroy 204    0.2097 2021-08-26

# %%
# running on multiple lemmas
# reg <- map_dfr(lemmas, ~compLemma(.x, file.path(input_dir, .x), file.path(output_dir, .x)))
# write_tsv(reg, file.path(output_dir, "euclidean_register.tsv"))

# %% [markdown]
# ## Medoids
#
# The medoids are simply calculated with `cluster::pam` and some basic information is stored in a `[lemma].medoids.tsv` file. The only important column for the visualization is `medoids`.

# %%
distmtx <- read_tsv(file.path(output_dir, lemma, paste0(lemma, ".models.dist.tsv")),
        col_types = cols()) %>% 
matricizeCloud() %>% as.dist
pam_data <- cluster::pam(distmtx, k = 8)

# %%
medoid_data <- pam_data$clusinfo %>% as_tibble() %>% mutate(medoids = pam_data$medoids, medoid_i = seq(8))
write_tsv(medoid_data, file.path(output_dir, lemma, paste0(lemma, ".medoids.tsv")))
medoid_data
# Out:
#   size max_diss av_diss  diameter separation
# 1 33   3.626162 2.430053 4.136572 1.0001767
# 2 29   3.726072 2.550195 4.159720 1.0001767
# 3 20   3.430102 2.620707 4.230553 1.8067634
# 4 21   3.681010 2.335795 4.175897 0.7574642
# 5 25   4.000107 2.528835 4.495695 0.7574642
# 6 17   3.320142 2.493338 4.062809 1.1197924
# 7 31   2.979151 2.220707 4.093892 1.1197924
# 8 28   3.292718 2.301664 4.081487 1.8669176
#   medoids                                                   medoid_i
# 1 destroy.LEMMAPATHweight.PPMIselection.LENGTHFOC.SOCPOSall 1
# 2 destroy.LEMMAREL2.PPMIselection.LENGTHFOC.SOCPOSall       2
# 3 destroy.bound5-5all.PPMIno.LENGTHFOC.SOCPOSall            3
# 4 destroy.bound10-10lex.PPMIselection.LENGTHFOC.SOCPOSall   4
# 5 destroy.nobound10-10all.PPMIweight.LENGTHFOC.SOCPOSall    5
# 6 destroy.nobound3-3all.PPMIselection.LENGTH5000.SOCPOSnav  6
# 7 destroy.bound3-3lex.PPMIselection.LENGTHFOC.SOCPOSall     7
# 8 destroy.bound5-5lex.PPMIselection.LENGTHFOC.SOCPOSall     8

# %%
# we can also add clustering data to the models summary
models_file <- file.path(output_dir, lemma, paste0(lemma, ".models.tsv"))
read_tsv(models_file, col_types = cols()) %>% 
    mutate(
        pam_cluster = pam_data$clustering[`_model`], # add pam-cluster number
        medoid = pam_data$medoids[pam_cluster] # add name of medoid
    ) %>% 
    write_tsv(models_file)

# %%
# On a loop
# for (lemma in lemmas) {
#     distmtx <- read_tsv(file.path(output_dir, lemma, paste0(lemma, ".models.dist.tsv")),
#         col_types = cols()) %>% 
#     matricizeCloud() %>% as.dist
#     pam_data <- cluster::pam(distmtx, k = 8)
#     medoid_data <- pam_data$clusinfo %>% as_tibble() %>% mutate(medoids = pam_data$medoids, medoid_i = seq(8))
#     write_tsv(medoid_data, file.path(output_dir, lemma, paste0(lemma, ".medoids.tsv")))
#     models_file <- file.path(output_dir, lemma, paste0(lemma, ".models.tsv"))
#     read_tsv(models_file, col_types = cols()) %>% 
#         mutate(
#             pam_cluster = pam_data$clustering[`_model`], # add pam-cluster number
#             medoid = pam_data$medoids[pam_cluster] # add name of medoid
#         ) %>% 
#         write_tsv(models_file)
# }

# %% [markdown]
# ## HDBSCAN
#
# I've mostly computed HDBSCAN among the medoids, but it could certainly be computed for all models. HDBSCAN information, from clustering to membership probabilities or eps, *could* in principle be included for NephoVis, but I haven't done it because the result varies per model, meaning that each token will have about 200 columns for each of them (or 8 if it's only with the medoids, which it's still a lot), and that is hard to incorporate into the tool.
#
# Instead, I work with an RDS file with a list of models per lemma, and each model object includes:
#
# - coordinates: the coordinates from t-SNE with perplexity 30, next to other variables in the "variables" dataframe like, in my case, "senses", as well as the tailored list of context words. We add the token-wise HDBSCAN info here
# - cws: distribution of first-order context words across HDBSCAN clusters and their t-SNE coordinates if available
# - (optionally) the normal HDBSCAN plot

# %%
# You could run it on all the models or just the medoids
# models <- read_tsv(file.path(output_dir, lemma, paste0(lemma, ".models.tsv")), col_types = cols())$`_model` # all models
models <- read_tsv(file.path(output_dir, lemma, paste0(lemma, ".medoids.tsv")), col_types = cols())$medoids # only medoids
models
# Out:
# [1] "destroy.LEMMAPATHweight.PPMIselection.LENGTHFOC.SOCPOSall"
# [2] "destroy.LEMMAREL2.PPMIselection.LENGTHFOC.SOCPOSall"
# [3] "destroy.bound5-5all.PPMIno.LENGTHFOC.SOCPOSall"
# [4] "destroy.bound10-10lex.PPMIselection.LENGTHFOC.SOCPOSall"
# [5] "destroy.nobound10-10all.PPMIweight.LENGTHFOC.SOCPOSall"
# [6] "destroy.nobound3-3all.PPMIselection.LENGTH5000.SOCPOSnav"
# [7] "destroy.bound3-3lex.PPMIselection.LENGTHFOC.SOCPOSall"
# [8] "destroy.bound5-5lex.PPMIselection.LENGTHFOC.SOCPOSall"

# %%
res <- map(setNames(models, models),
           summarizeHDBSCAN, lemma = lemma,
           input_dir = file.path(input_dir, lemma),
           output_dir = file.path(output_dir, lemma))
write_rds(list("destroy" = res), file.path(output_dir, "hdbscan.rds"))

# %%
names(res)
# Out:
# [1] "destroy.LEMMAPATHweight.PPMIselection.LENGTHFOC.SOCPOSall"
# [2] "destroy.LEMMAREL2.PPMIselection.LENGTHFOC.SOCPOSall"
# [3] "destroy.bound5-5all.PPMIno.LENGTHFOC.SOCPOSall"
# [4] "destroy.bound10-10lex.PPMIselection.LENGTHFOC.SOCPOSall"
# [5] "destroy.nobound10-10all.PPMIweight.LENGTHFOC.SOCPOSall"
# [6] "destroy.nobound3-3all.PPMIselection.LENGTH5000.SOCPOSnav"
# [7] "destroy.bound3-3lex.PPMIselection.LENGTHFOC.SOCPOSall"
# [8] "destroy.bound5-5lex.PPMIselection.LENGTHFOC.SOCPOSall"

# %%
res[[1]]$coords
# Out:
#     _id                                                   model.x
# 1   verniel/verb/volkskrant_19990517_122/16                 2.8988544
# 2   verniel/verb/het_nieuwsblad_20030830_01_369/154        -1.6853307
# 3   verniel/verb/parool_20040309_16/329                   -16.6766356
# 4   verniel/verb/het_laatste_nieuws_20000306_01_201/52     -5.6305850
# 5   verniel/verb/het_laatste_nieuws_20041112_01_230/104    -9.9646824
# 6   verniel/verb/het_laatste_nieuws_20001219_01_282/59     -7.3809673
# 7   verniel/verb/parool_20010412_58/69                      3.2812238
# 8   verniel/verb/het_nieuwsblad_20031105_01_340/198        -6.3526612
# 9   verniel/verb/parool_20001229_14/17                     -1.6465688
# 10  verniel/verb/het_laatste_nieuws_20040320_01_388/70    -19.9197007
# 11  verniel/verb/algemeen_dagblad_20000325_147/15          -4.6980745
# 12  verniel/verb/het_laatste_nieuws_20020102_01_119/67     -7.6566396
# 13  verniel/verb/nrc_handelsblad_20000405_153/853           2.3690433
# 14  verniel/verb/het_laatste_nieuws_20001127_01_571/210   -16.5873190
# 15  verniel/verb/het_laatste_nieuws_20041213_01_32/34     -20.8201371
# 16  verniel/verb/parool_20030912_51/170                    -5.9042194
# 17  verniel/verb/algemeen_dagblad_20000405_72/99           -5.9953457
# 18  verniel/verb/algemeen_dagblad_20000508_82/42           -0.2778859
# 19  verniel/verb/nrc_handelsblad_20000609_11/74            -1.7094271
# 20  verniel/verb/volkskrant_20000605_3/211                 -4.3593325
# 21  verniel/verb/het_laatste_nieuws_20030319_01_245/53     -2.1762969
# 22  verniel/verb/de_morgen_20041211_01_99/79              -12.3899229
# 23  verniel/verb/het_nieuwsblad_20000626_01_118/176       -11.2268155
# 24  verniel/verb/het_nieuwsblad_20020518_01_498/173       -16.7425099
# 25  verniel/verb/het_nieuwsblad_20030927_01_817/15         -8.6539385
# 26  verniel/verb/parool_20030614_107/376                  -11.8770138
# 27  verniel/verb/het_nieuwsblad_19990324_01_465/64        -17.4709436
# 28  verniel/verb/het_laatste_nieuws_20000413_01_136/178   -10.7341648
# 29  verniel/verb/het_nieuwsblad_20040719_01_246/133       -15.1340964
# 30  verniel/verb/het_laatste_nieuws_20040630_01_152/134    -5.5581122
# ⋮   ⋮                                                     ⋮
# 431 vernietig/verb/de_morgen_20001205_01_64/408            21.4301707
# 432 vernietig/verb/de_standaard_19990312_01_64/236         13.9929369
# 433 vernietig/verb/nrc_handelsblad_19990106_121/108        23.0091118
# 434 vernietig/verb/algemeen_dagblad_20000414_111/37        22.1779544
# 435 vernietig/verb/de_morgen_20010316_01_155/130            0.4529468
# 436 vernietig/verb/parool_20011030_47/64                   20.2112024
# 437 vernietig/verb/algemeen_dagblad_20010323_152/41         1.2841236
# 438 vernietig/verb/het_nieuwsblad_20021102_01_538/141      12.9751184
# 439 vernietig/verb/de_morgen_20030203_01_45/461             9.4232847
# 440 vernietig/verb/de_morgen_20030918_01_51/90             10.4299324
# 441 vernietig/verb/nrc_handelsblad_20011222_29/21          12.4630895
# 442 vernietig/verb/nrc_handelsblad_20020921_19/198        -19.3624120
# 443 vernietig/verb/volkskrant_20010413_123/73              13.8183033
# 444 vernietig/verb/volkskrant_19991210_14/119              -6.8271380
# 445 vernietig/verb/de_standaard_20030520_01_6/386         -11.3217802
# 446 vernietig/verb/algemeen_dagblad_20001201_49/300        23.6652835
# 447 vernietig/verb/de_standaard_20030212_01_20/128         22.1425447
# 448 vernietig/verb/parool_20010222_30/60                   12.0765955
# 449 vernietig/verb/volkskrant_20000928_64/91               -0.2615267
# 450 vernietig/verb/nrc_handelsblad_20000126_94/317         11.1979137
# 451 vernietig/verb/het_laatste_nieuws_19990622_01_341/140 -13.2496111
# 452 vernietig/verb/algemeen_dagblad_20040228_03/33        -14.8140143
# 453 vernietig/verb/volkskrant_19990113_29/54               -2.8520897
# 454 vernietig/verb/de_standaard_20040807_01_89/32          18.9074777
# 455 vernietig/verb/het_nieuwsblad_20020508_01_298/29      -12.2561294
# 456 verniel/verb/volkskrant_20010116_48/18                 12.8575425
# 457 verniel/verb/het_laatste_nieuws_20041210_01_387/54      2.1751267
# 458 vernietig/verb/de_standaard_20030703_01_20/165         22.2525713
# 459 vernietig/verb/de_standaard_20030416_01_129/251       -20.5770170
# 460 vernietig/verb/algemeen_dagblad_20011026_70/36         21.4504695
#     model.y
# 1   -22.462862
# 2   -19.225090
# 3   -12.206250
# 4   -29.800029
# 5    -3.892588
# 6   -40.659280
# 7   -21.938489
# 8   -38.054513
# 9   -36.451938
# 10  -18.306144
# 11  -28.054751
# 12   -4.144373
# 13  -40.561491
# 14  -24.906478
# 15  -21.067193
# 16   11.813858
# 17   19.279312
# 18  -14.973804
# 19  -14.419980
# 20  -26.494880
# 21  -40.775664
# 22  -19.376371
# 23    4.852852
# 24   15.377679
# 25   -6.452942
# 26  -14.807840
# 27  -21.906561
# 28   -2.621493
# 29  -25.962555
# 30  -27.804202
# ⋮   ⋮
# 431  29.5425463
# 432  26.5523115
# 433   8.0532561
# 434  34.6099446
# 435   9.9263000
# 436  35.3571362
# 437  22.5055198
# 438  -4.6702774
# 439   0.7913685
# 440   4.7065358
# 441   0.2549384
# 442  15.7006344
# 443  23.6131255
# 444  -0.7398779
# 445  10.1754615
# 446   5.1996999
# 447  12.4159583
# 448  25.1790929
# 449  -6.7614317
# 450   4.9521410
# 451  20.1737404
# 452 -21.6199687
# 453   3.1750665
# 454  10.2077850
# 455  -1.7882446
# 456  30.2567529
# 457 -39.7990362
# 458  11.0798981
# 459  15.1966058
# 460  36.9152743
#     cws
# 1   een/det           , Picasso/name      , ben/verb          , Stedelijk/name    , het/det           , schilderij/noun   , ernstig/adj       , zondag_middag/noun, van/prep          , Museum/name       , mes/noun
# 2   de/det         , afsluiting/noun, waarbij/pp     , en/vg          , van/prep       , poort/noun
# 3   toen/comp    , de/det       , word/verb    , stort_in/verb, vorige/adj   , deels/adv    , woensdag/noun
# 4   een/det                       , de/det                        , 58-jarige/adj                 , elektriciteit_voorziening/noun, vrijdag_morgen/noun           , heb/verb                      , bulldozer/noun                , paar/noun                     , en/vg                         , van/prep                      , woning/noun                   , auto/noun
# 5   Brugge/name, de/det     , word/verb  , waardoor/pp, stad/noun
# 6   ben/verb              , betrap/verb           , kerst_verlichting/noun
# 7   Stedelijk/name , het/det        , schilderij/noun, word/verb      , of/vg          , 1998/noun      , van/prep       , Museum/name
# 8   de/det       , camera/noun  , Werchter/name, onbekend/adj
# 9   een/det       , geparkeerd/adj, de/det        , Mercedes/name , zwaar/adj     , heb/verb
# 10  een/det             , bij_gebouw/noun     , brand/noun          , de/det              , schrijnwerkerij/noun, zwaar/adj           , ontsta/verb         , van/prep
# 11  omdat/comp       , een/det          , ben/verb         , de/det           , vracht_wagen/noun, bovenleiding/noun, heb/verb         , buurt/noun
# 12  de/det              , word/verb           , en/vg               , kerstversiering/noun, van/prep
# 13  breek_open/verb, ze/pron        , open/part      , alles/noun     , en/vg          , auto/noun
# 14  ben/verb    , de/det      , kerk/noun   , dak/noun    , en/vg       , volledig/adj, van/prep
# 15  een/det             , de/det              , achter_bouw/noun    , gas_ontploffing/noun, enorm/adj           , vooravond/noun      , van/prep            , woning/noun
# 16  word/verb    , er/adv       , niets/noun   , verstoor/verb
# 17  omdat/comp    , ben/verb      , veel/det      , bouw_werk/noun
# 18  de/det         , heb/verb       , en/vg          , van/prep       , rest/noun      , inventaris/noun
# 19  tachtig/num , ben/verb    , de/det      , volgens/prep, van/prep    , huis/noun
# 20  ben/verb         , bovenleiding/noun, rail/noun        , dwarsligger/noun , meter/noun       , honderden/noun   , en/vg
# 21  een/det       , bloem_bak/noun, word/verb
# 22  bombardement/noun, het/det          , de/det           , bijna/adv        , word/verb        , door/prep        , gebouw/noun      , volledig/adj
# 23  een/det      , word/verb    , voorraad/noun
# 24  divers/adj  , ben/verb    , machine/noun
# 25  Benetton/name  , de/det         , 1994/num       , Schumacher/name, tijdens/prep   , en/vg
# 26  een/det     , word/verb   , verlaten/adj, bos/noun
# 27  de/det         , word/verb      , rij_woning/noun, compleet/adj
# 28  de/det      , word/verb   , school/noun , tijdens/prep
# 29  ben/verb    , de/det      , volledig/adj
# 30  word/verb     , verhinder/verb, twee/num      , tractor/noun
# ⋮   ⋮
# 431 het/det             , dat/det             , vonnis/noun         , heb/verb            , hooggerechtshof/noun
# 432 beslissing/noun, die/det        , het/det        , weiger/verb    , de/det         , als/comp       , regering/noun  , of/vg          , omwille/prep   , kan/verb
# 433 om/comp  , te/comp  , laat/verb
# 434 omdat/comp        , intrekking/noun   , ben/verb          , het/det           , de/det            , zal/verb          , anders/adj        , Hoge/name         , volgens/prep      , recht_college/noun
# 435 word/verb         , strijdig/adj      , boeddha_beeld/noun, bevel/noun        , moet/verb
# 436 ben/verb      , die/det       , de/det        , door/prep     , Hoge/name     , uitspraak/noun, Raad/name
# 437 gen/noun, dat/pron
# 438 ervan/pp    , granaat/noun, men/pron    , 2.800/num   , kan/verb
# 439 die/det               , de/det                , doel/noun             , veiligheid_dienst/noun, garde/noun            , politie/noun          , en/vg                 , moet/verb
# 440 zoals/comp, het/det   , de/det    , bijna/adv , al/adv    , heb/verb  , Irak/name , wat/pron
# 441 gevecht_vliegtuig/noun, Amerikaans/adj        , konvooi/noun          , heb/verb              , Afghanistan/name
# 442 ben/verb      , aan/comp      , waarde/noun   , rendement/noun, Stanley/name  , het/comp
# 443 om/comp     , het/det     , word/verb   , besluit/noun
# 444 omdat/comp        , administratie/noun, de/det            , word/verb         , tijdens/prep      , opstand/noun
# 445 zal/verb    , word/verb   , jaag_op/verb, en/vg
# 446 ben/verb , te/comp  , of/vg    , door/comp
# 447 die/det   , het/det   , geval/noun, te/comp   , doel/noun
# 448 het/det             , door/prep           , onderdeel/noun      , bestemming_plan/noun, daarmee/pp          , gisteren/adv
# 449 wil/verb, de/det  , die/pron, heel/adj
# 450 het/det         , de/det          , regime/noun     , integriteit/noun, heb/verb        , Sharif/name     , laat/verb       , en/vg
# 451 dood/verb  , word/verb  , varken/noun, en/vg
# 452 inboedel/noun, ben/verb     , mag/verb     , de/det       , daarna/pp    , en/vg
# 453 rebel/noun   , zeg/verb     , alles/noun   , en/vg        , verbrand/verb
# 454 heffing/noun     , om/comp          , de/det           , te/comp          , farmaceutisch/adj, overheid/noun
# 455 het/det     , de/det      , word/verb   , tijdens/prep
# 456 het/det              , wegens/prep          , gevangenis_straf/noun, hang/verb            , van/prep
# 457 dief/noun      , breek_open/verb, twee/num       , open/part      , en/vg          , van/prep
# 458 om/comp, het/det, te/comp
# 459 ben/verb, al/adv  , daar/adv
# 460 het/det    , de/det     , vonnis/noun, heb/verb   , Raad/name  , State/name , van/name
#     clusters membprob    eps
# 1   0        0.000000000 3.887423
# 2   0        0.000000000 3.186496
# 3   0        0.000000000 2.897787
# 4   4        0.000000000 2.826265
# 5   5        0.003507536 3.135761
# 6   0        0.000000000 3.544540
# 7   0        0.000000000 3.884736
# 8   3        0.007459628 2.767327
# 9   3        0.094472841 2.524723
# 10  4        0.215657534 2.216760
# 11  0        0.000000000 3.132236
# 12  0        0.000000000 3.290319
# 13  3        0.166107615 2.324997
# 14  4        0.164498291 2.361349
# 15  4        0.147294679 2.409971
# 16  5        0.001909823 3.140788
# 17  0        0.000000000 4.120686
# 18  0        0.000000000 3.429256
# 19  0        0.000000000 3.438824
# 20  0        0.000000000 3.871700
# 21  0        0.000000000 2.990643
# 22  0        0.000000000 3.006254
# 23  0        0.000000000 3.800653
# 24  0        0.000000000 4.084635
# 25  0        0.000000000 3.994541
# 26  0        0.000000000 3.635617
# 27  4        0.047339499 2.692471
# 28  5        0.013608514 3.103975
# 29  4        0.069445728 2.629993
# 30  0        0.000000000 3.370444
# ⋮   ⋮        ⋮           ⋮
# 431 2        0.10012217  2.855616
# 432 0        0.00000000  3.232229
# 433 1        0.30109195  2.256317
# 434 2        0.25541556  2.362817
# 435 0        0.00000000  3.515170
# 436 2        0.28094853  2.281793
# 437 0        0.00000000  3.892270
# 438 0        0.00000000  3.987783
# 439 0        0.00000000  3.733213
# 440 0        0.00000000  3.877019
# 441 0        0.00000000  3.540125
# 442 0        0.00000000  4.312307
# 443 0        0.00000000  3.406074
# 444 5        0.01276436  3.106631
# 445 5        0.07492564  2.911022
# 446 1        0.07659869  2.981059
# 447 0        0.00000000  3.419933
# 448 0        0.00000000  3.460278
# 449 0        0.00000000  3.674193
# 450 0        0.00000000  3.828237
# 451 0        0.00000000  3.223494
# 452 0        0.00000000  3.385437
# 453 0        0.00000000  3.833004
# 454 1        0.21233921  2.542841
# 455 0        0.00000000  3.279800
# 456 0        0.00000000  3.796423
# 457 3        0.19200247  2.252799
# 458 1        0.15178506  2.738331
# 459 0        0.00000000  4.481518
# 460 2        0.39224840  1.928601

# %%
res[[2]]$cws %>% filter(cluster == 1)
# Out:
#   cw            TP recall precision Fscore    cluster model.x    model.y
# 1 ben/verb      8  1.000  0.1509434 0.2622951 1       -32.982993  18.18119
# 2 practisch/adj 1  0.125  1.0000000 0.2222222 1       -11.542693  14.97918
# 3 daar/adv      1  0.125  0.5000000 0.2000000 1        12.159312 -20.77912
# 4 stad/noun     1  0.125  0.3333333 0.1818182 1         6.602981 -23.25507

# %% [markdown]
# I've typically stored this data somewhere else, not really on the visualization GitHub, but it could totally go there. It is more useful for the ShinyApp though.

# %%
# On a loop across lemmas
# map(setNames(lemmas, lemmas), function(lemma){
#     map(setNames(models, models),
#            summarizeHDBSCAN, lemma = lemma,
#            input_dir = file.path(input_dir, lemma),
#            output_dir = file.path(output_dir, lemma))
# }) %>% 
# write_rds(file.path(output_dir, "hdbscan.rds"))

# %% [markdown]
# ### What to do with HDBSCAN
#
# Here I will add the code to classify the clouds in types, but later.

# %% [markdown]
# ## Final steps
#
# For the visualization tool, we need to add a file that lists all the files in the directory of a lemma, to help it manage the available data.

# %%
library(stringr)
library(readr)
library(purrr)
library(rjson)
cleanFname <- function(str){
    sections <- str_split(str, "\\.")[[1]]
    paste(sections[-c(1, length(sections))], collapse = "")
}

# %%
output_dir <- "../github/"
lemma <- "destroy"

# %%
files_list <- dir(file.path(output_dir, lemma))
names(files_list) <- map_chr(files_list, cleanFname)
files_list
# Out:
#                   medoids                modelsdist                    models
#     "destroy.medoids.tsv" "destroy.models.dist.tsv"      "destroy.models.tsv"
#                      ppmi                 solutions                 tsne30cws
#        "destroy.ppmi.tsv"  "destroy.solutions.json" "destroy.tsne.30.cws.tsv"
#                    tsne30                 variables
#     "destroy.tsne.30.tsv"   "destroy.variables.tsv"

# %%
write(toJSON(files_list), file.path(output_dir, lemma, "paths.json"))
fromJSON(file = file.path(output_dir, lemma, "paths.json"))
# Out:
# $medoids
# [1] "destroy.medoids.tsv"
#
# $modelsdist
# [1] "destroy.models.dist.tsv"
#
# $models
# [1] "destroy.models.tsv"
#
# $ppmi
# [1] "destroy.ppmi.tsv"
#
# $solutions
# [1] "destroy.solutions.json"
#
# $tsne30cws
# [1] "destroy.tsne.30.cws.tsv"
#
# $tsne30
# [1] "destroy.tsne.30.tsv"
#
# $variables
# [1] "destroy.variables.tsv"

# %%
# On a loop across lemmas
# for (lemma in lemma){
#     files_list <- dir(file.path(output_dir, lemma))
#     names(files_list) <- map_chr(files_list, cleanFname)
#     write(toJSON(files_list), file.path(output_dir, lemma, "paths.json"))
# }
