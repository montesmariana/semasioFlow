# %% [markdown]
# # From distances to clouds
#
# The R half of the workflow takes care of the distance matrices and generates the rest of the files that we need for the visualization itself:
#
# - The coordinates to plot the tokens and context words
# - The distances between models
# - The coordinates to plot the models
# - Selection of medoids
# - HDBSCAN clustering

# %% [markdown]
# **note:**
#
# I tested everything on the original code as an R script, but only some things with the code as an R package. If anything doesn't work, please let me know (with an [issue](https://github.com/montesmariana/semcloud/issues/new/choose) or by mail).

# %%
#devtools::install_github("montesmariana/semcloud")
# Out:
# Downloading GitHub repo montesmariana/semcloud@HEAD
# ✔  checking for file ‘/tmp/RtmpQgR9MS/remotes8a973752abac/montesmariana-semcloud-a965e48/DESCRIPTION’
# ─  preparing ‘semcloud’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘semcloud_0.0.0.9000.tar.gz’
# Installing package into ‘/home/mariana/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
library(semcloud)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
input_dir <- "../output/tokens" # where the data is stored
cw_dir <- "../output/cws"
output_dir <- "../github/" # where the data will go

# %%
lemmas <- setdiff(dir(input_dir), c('destroy', 'eatdrink'))

# %% [markdown]
# ## Token coordinates
#
# In order to compute the token coordinates, we first need to decide which solutions we are going to choose,
# that is, whether we are going to run nMDS and, in the case we run t-SNE, which perplexities we are interested in.
# We might even want to run UMAP (not available yet in this code).
#
# While in the end I mostly looked at t-SNE with perplexity of 30, I will show the instructions when having more options.

# %%
# This list works for a loop in the function below and should then be stored as a json file
# in the github directory of each lemma, to tell the visualization what is being used
solutions_old <- list("mds" = ".mds")
for (perp in c(10, 20, 30, 50)) {
    solutions_old[[paste0("tsne", perp)]] = paste0(".tsne.", perp)
}
solutions_old

# %%
# For show at least, we will only use t-SNE 30, but the same should be done anyways
solutions <- list("tsne30" = ".tsne.30")

# %%
# If we have a many lemmas, we could run this on a loop:
suffix <- ".ttmx.dist.pac"
for (lemma in lemmas) {
    models_file <- file.path(output_dir, lemma, paste0(lemma, '.models.tsv'))
    files_list <- paste0(read_tsv(models_file, col_types = cols())$`_model`, suffix)
    write(rjson::toJSON(solutions), file.path(output_dir, lemma, paste0(lemma, ".solutions.json")))    
    getClouds(file.path(input_dir, lemma), file.path(output_dir, lemma),
          files_list, lemma, solutions)
}
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%

# %% [markdown]
# ## Context words coordinates
# For the context words, the workflow is exactly the same as for the tokens. The difference is that the files are saved as `.csv` (because for some reason R cannot read them when they are `.wwmx...` and so it uses the `focdistsFromCsv()` function.

# %%
# If we have a many lemmas, we could run this on a loop:
suffix <- ".wwmx.dist.csv"
for (lemma in lemmas) {
    models_file <- file.path(output_dir, lemma, paste0(lemma, '.models.tsv'))
    files_list <- paste0(read_tsv(models_file, col_types = cols())$`_model`, suffix)
    getClouds(file.path(cw_dir, lemma), file.path(output_dir, lemma),
          files_list, lemma, solutions, type = 'focdists')
}
# Out:
# Error in getClouds(file.path(cw_dir, lemma), file.path(output_dir, lemma), : object 'solutions' not found
# Traceback:
#
# 1. getClouds(file.path(cw_dir, lemma), file.path(output_dir, lemma),
#  .     files_list, lemma, solutions, type = "focdists")
# 2. purrr::map(solutions, function(solution) {
#  .     suffix <- if (type == "token")
#  .         ".tsv"
#  .     else ".cws.tsv"
#  .     filename.full <- file.path(output_dir, paste0(lemma, solution,
#  .         suffix))
#  .     df <- if (file.exists(filename.full))
#  .         readr::read_tsv(filename.full, col_types = readr::cols())
#  .     else ""
#  .     return(list(filename = filename.full, df = df))
#  . })

# %% [markdown]
# ## Model distances and coordinates
#
# The function belows loads the `[lemma].models.tsv` file in the `output_dir` in order to modify it by appending the coordinates from an nMDS on the distances between the models. By default, it will compute "euclidean" distances on the transformed matrices, but the function can be changed with the `fun` argument, and the transformation can be turned off with the `transformed` argument. It returns some data for a register (which I tend to combine across lemmas and store as `euclidean_register.tsv` to tell the index of the visualization which lemmas to offer :)
#
# Under the hood, it also stores the distance matrix as `[lemma].models.dist.tsv`. If the file already exists, it loads it instead of recomputing the distances.

# %%
# running on multiple lemmas
reg <- map_dfr(lemmas, ~compLemma(.x, file.path(input_dir, .x), file.path(output_dir, .x)))
write_tsv(reg, file.path(output_dir, "euclidean_register.tsv"))
# Out:
# Run 0 stress 0.1421042
# Run 1 stress 0.1625272
# Run 2 stress 0.1717681
# Run 3 stress 0.1651881
# Run 4 stress 0.1706972
# Run 5 stress 0.1545158
# Run 6 stress 0.1908481
# Run 7 stress 0.183644
# Run 8 stress 0.2226687
# Run 9 stress 0.1853079
# Run 10 stress 0.1681442
# Run 11 stress 0.1900465
# Run 12 stress 0.1904087
# Run 13 stress 0.1841634
# Run 14 stress 0.1715881
# Run 15 stress 0.1653993
# Run 16 stress 0.1421042
# ... Procrustes: rmse 4.371464e-05  max resid 0.000259483
# ... Similar to previous best
# Run 17 stress 0.1421041
# ... New best solution
# ... Procrustes: rmse 2.828685e-05  max resid 0.0001829588
# ... Similar to previous best
# Run 18 stress 0.1651976
# Run 19 stress 0.1981996
# Run 20 stress 0.1668781
# *** Solution reached
# [1] 0.1421041
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//diskwalificeren/diskwalificeren.models.dist.tsv"
# Run 0 stress 0.1895059
# Run 1 stress 0.1939067
# Run 2 stress 0.1927536
# Run 3 stress 0.2220217
# Run 4 stress 0.2172796
# Run 5 stress 0.1932771
# Run 6 stress 0.2172565
# Run 7 stress 0.1895133
# ... Procrustes: rmse 0.0002150345  max resid 0.001506671
# ... Similar to previous best
# Run 8 stress 0.189506
# ... Procrustes: rmse 7.124027e-05  max resid 0.0005033364
# ... Similar to previous best
# Run 9 stress 0.1895068
# ... Procrustes: rmse 0.0002737592  max resid 0.003005424
# ... Similar to previous best
# Run 10 stress 0.2169518
# Run 11 stress 0.1895058
# ... New best solution
# ... Procrustes: rmse 1.491449e-05  max resid 8.25456e-05
# ... Similar to previous best
# Run 12 stress 0.1895059
# ... Procrustes: rmse 2.18901e-05  max resid 0.0001469963
# ... Similar to previous best
# Run 13 stress 0.1895058
# ... Procrustes: rmse 1.042413e-05  max resid 9.961886e-05
# ... Similar to previous best
# Run 14 stress 0.1895068
# ... Procrustes: rmse 0.000274033  max resid 0.003009463
# ... Similar to previous best
# Run 15 stress 0.1939067
# Run 16 stress 0.2170217
# Run 17 stress 0.1895068
# ... Procrustes: rmse 0.0002740482  max resid 0.00300876
# ... Similar to previous best
# Run 18 stress 0.1895058
# ... Procrustes: rmse 4.625601e-06  max resid 3.479728e-05
# ... Similar to previous best
# Run 19 stress 0.1895058
# ... Procrustes: rmse 5.684374e-06  max resid 4.000743e-05
# ... Similar to previous best
# Run 20 stress 0.1932772
# *** Solution reached
# [1] 0.1895058
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//dof/dof.models.dist.tsv"
# Run 0 stress 0.1807598
# Run 1 stress 0.1807598
# ... Procrustes: rmse 1.19897e-05  max resid 5.786873e-05
# ... Similar to previous best
# Run 2 stress 0.1807598
# ... New best solution
# ... Procrustes: rmse 2.006128e-05  max resid 9.418455e-05
# ... Similar to previous best
# Run 3 stress 0.1807598
# ... New best solution
# ... Procrustes: rmse 1.153473e-05  max resid 6.798669e-05
# ... Similar to previous best
# Run 4 stress 0.4165543
# Run 5 stress 0.1807598
# ... New best solution
# ... Procrustes: rmse 6.661572e-06  max resid 5.929846e-05
# ... Similar to previous best
# Run 6 stress 0.1807598
# ... Procrustes: rmse 1.241526e-05  max resid 0.0001430158
# ... Similar to previous best
# Run 7 stress 0.1807598
# ... Procrustes: rmse 1.443097e-05  max resid 0.0001021992
# ... Similar to previous best
# Run 8 stress 0.1807598
# ... Procrustes: rmse 2.288187e-05  max resid 0.0002127928
# ... Similar to previous best
# Run 9 stress 0.1807598
# ... Procrustes: rmse 1.288156e-05  max resid 7.260308e-05
# ... Similar to previous best
# Run 10 stress 0.1807598
# ... Procrustes: rmse 1.605635e-05  max resid 9.891388e-05
# ... Similar to previous best
# Run 11 stress 0.1807598
# ... Procrustes: rmse 2.535497e-05  max resid 0.0003216637
# ... Similar to previous best
# Run 12 stress 0.1807598
# ... Procrustes: rmse 2.211778e-05  max resid 0.0001239334
# ... Similar to previous best
# Run 13 stress 0.1807598
# ... Procrustes: rmse 1.260734e-05  max resid 0.0001304407
# ... Similar to previous best
# Run 14 stress 0.1807598
# ... Procrustes: rmse 1.759175e-05  max resid 0.0001029377
# ... Similar to previous best
# Run 15 stress 0.1807598
# ... Procrustes: rmse 1.907134e-05  max resid 0.0001157301
# ... Similar to previous best
# Run 16 stress 0.1807598
# ... Procrustes: rmse 1.380684e-05  max resid 8.467387e-05
# ... Similar to previous best
# Run 17 stress 0.1807598
# ... Procrustes: rmse 6.551932e-06  max resid 5.382902e-05
# ... Similar to previous best
# Run 18 stress 0.1807598
# ... Procrustes: rmse 1.533651e-05  max resid 0.0001193718
# ... Similar to previous best
# Run 19 stress 0.1807598
# ... Procrustes: rmse 1.184179e-05  max resid 7.125232e-05
# ... Similar to previous best
# Run 20 stress 0.1807598
# ... Procrustes: rmse 1.45682e-05  max resid 7.030316e-05
# ... Similar to previous best
# *** Solution reached
# [1] 0.1807598
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//geestig/geestig.models.dist.tsv"
# Run 0 stress 0.200401
# Run 1 stress 0.2407616
# Run 2 stress 0.2012189
# Run 3 stress 0.20041
# ... Procrustes: rmse 0.0006609085  max resid 0.008319587
# ... Similar to previous best
# Run 4 stress 0.2350802
# Run 5 stress 0.2118071
# Run 6 stress 0.200401
# ... Procrustes: rmse 2.956356e-05  max resid 0.0002787417
# ... Similar to previous best
# Run 7 stress 0.2358577
# Run 8 stress 0.2004013
# ... Procrustes: rmse 0.0002868596  max resid 0.003645298
# ... Similar to previous best
# Run 9 stress 0.2018856
# Run 10 stress 0.200401
# ... New best solution
# ... Procrustes: rmse 1.0707e-05  max resid 7.208527e-05
# ... Similar to previous best
# Run 11 stress 0.2004713
# ... Procrustes: rmse 0.002540981  max resid 0.01562017
# Run 12 stress 0.2018337
# Run 13 stress 0.2012189
# Run 14 stress 0.2012189
# Run 15 stress 0.2004011
# ... Procrustes: rmse 6.471084e-05  max resid 0.0004842331
# ... Similar to previous best
# Run 16 stress 0.200401
# ... Procrustes: rmse 3.511954e-05  max resid 0.0002071386
# ... Similar to previous best
# Run 17 stress 0.2117558
# Run 18 stress 0.200401
# ... Procrustes: rmse 3.296637e-05  max resid 0.0002322793
# ... Similar to previous best
# Run 19 stress 0.2012189
# Run 20 stress 0.2004011
# ... Procrustes: rmse 4.707319e-05  max resid 0.0003639683
# ... Similar to previous best
# *** Solution reached
# [1] 0.200401
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//gekleurd/gekleurd.models.dist.tsv"
# Run 0 stress 0.163377
# Run 1 stress 0.1634017
# ... Procrustes: rmse 0.0007582587  max resid 0.006116821
# ... Similar to previous best
# Run 2 stress 0.1633775
# ... Procrustes: rmse 0.0002322537  max resid 0.002889239
# ... Similar to previous best
# Run 3 stress 0.1633775
# ... Procrustes: rmse 0.0002496116  max resid 0.003049169
# ... Similar to previous best
# Run 4 stress 0.163377
# ... Procrustes: rmse 1.933228e-05  max resid 0.0001405418
# ... Similar to previous best
# Run 5 stress 0.1633774
# ... Procrustes: rmse 0.0002452338  max resid 0.003070466
# ... Similar to previous best
# Run 6 stress 0.1634017
# ... Procrustes: rmse 0.0007721121  max resid 0.006228418
# ... Similar to previous best
# Run 7 stress 0.163377
# ... New best solution
# ... Procrustes: rmse 5.739994e-06  max resid 4.837268e-05
# ... Similar to previous best
# Run 8 stress 0.163377
# ... Procrustes: rmse 7.113745e-06  max resid 6.828345e-05
# ... Similar to previous best
# Run 9 stress 0.163377
# ... Procrustes: rmse 3.51219e-05  max resid 0.0003445794
# ... Similar to previous best
# Run 10 stress 0.1634019
# ... Procrustes: rmse 0.0008078625  max resid 0.00651348
# ... Similar to previous best
# Run 11 stress 0.1633774
# ... Procrustes: rmse 0.0001887074  max resid 0.002347784
# ... Similar to previous best
# Run 12 stress 0.163377
# ... Procrustes: rmse 4.220453e-06  max resid 3.134991e-05
# ... Similar to previous best
# Run 13 stress 0.1633771
# ... Procrustes: rmse 5.846331e-05  max resid 0.0007152022
# ... Similar to previous best
# Run 14 stress 0.1633775
# ... Procrustes: rmse 0.000234142  max resid 0.002840653
# ... Similar to previous best
# Run 15 stress 0.1633774
# ... Procrustes: rmse 0.0002134293  max resid 0.002670978
# ... Similar to previous best
# Run 16 stress 0.1633774
# ... Procrustes: rmse 0.000141874  max resid 0.001755332
# ... Similar to previous best
# Run 17 stress 0.1634017
# ... Procrustes: rmse 0.0007653752  max resid 0.006169051
# ... Similar to previous best
# Run 18 stress 0.163377
# ... Procrustes: rmse 2.259426e-05  max resid 0.0002013542
# ... Similar to previous best
# Run 19 stress 0.163377
# ... Procrustes: rmse 3.058869e-05  max resid 0.0003123157
# ... Similar to previous best
# Run 20 stress 0.1633774
# ... Procrustes: rmse 0.0002293944  max resid 0.002877957
# ... Similar to previous best
# *** Solution reached
# [1] 0.163377
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//geldig/geldig.models.dist.tsv"
# Run 0 stress 0.2062365
# Run 1 stress 0.2063523
# ... Procrustes: rmse 0.002739647  max resid 0.02456444
# Run 2 stress 0.2063544
# ... Procrustes: rmse 0.002931733  max resid 0.02465933
# Run 3 stress 0.2062365
# ... New best solution
# ... Procrustes: rmse 1.034653e-05  max resid 8.233001e-05
# ... Similar to previous best
# Run 4 stress 0.2140783
# Run 5 stress 0.2140832
# Run 6 stress 0.2062365
# ... Procrustes: rmse 1.114962e-05  max resid 4.34085e-05
# ... Similar to previous best
# Run 7 stress 0.2063285
# ... Procrustes: rmse 0.003212685  max resid 0.02452583
# Run 8 stress 0.2140771
# Run 9 stress 0.2062059
# ... New best solution
# ... Procrustes: rmse 0.00142502  max resid 0.01920737
# Run 10 stress 0.2062059
# ... New best solution
# ... Procrustes: rmse 2.701144e-05  max resid 0.0001378765
# ... Similar to previous best
# Run 11 stress 0.2140783
# Run 12 stress 0.2062059
# ... New best solution
# ... Procrustes: rmse 2.576034e-05  max resid 9.98844e-05
# ... Similar to previous best
# Run 13 stress 0.2062059
# ... New best solution
# ... Procrustes: rmse 1.05525e-05  max resid 5.095003e-05
# ... Similar to previous best
# Run 14 stress 0.2063543
# ... Procrustes: rmse 0.003261077  max resid 0.02472945
# Run 15 stress 0.2140831
# Run 16 stress 0.2067143
# Run 17 stress 0.2063285
# ... Procrustes: rmse 0.002897772  max resid 0.0245616
# Run 18 stress 0.2062365
# ... Procrustes: rmse 0.001425123  max resid 0.01921316
# Run 19 stress 0.2063542
# ... Procrustes: rmse 0.003245916  max resid 0.02470297
# Run 20 stress 0.2062365
# ... Procrustes: rmse 0.001428333  max resid 0.01924995
# *** Solution reached
# [1] 0.2062059
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//gemeen/gemeen.models.dist.tsv"
# Run 0 stress 0.2037874
# Run 1 stress 0.2040316
# ... Procrustes: rmse 0.007890446  max resid 0.05004025
# Run 2 stress 0.2048543
# Run 3 stress 0.203589
# ... New best solution
# ... Procrustes: rmse 0.003811731  max resid 0.05163345
# Run 4 stress 0.2039595
# ... Procrustes: rmse 0.006208492  max resid 0.06013063
# Run 5 stress 0.2044985
# Run 6 stress 0.2043434
# Run 7 stress 0.2039595
# ... Procrustes: rmse 0.00620935  max resid 0.06012916
# Run 8 stress 0.204854
# Run 9 stress 0.2042085
# Run 10 stress 0.204053
# ... Procrustes: rmse 0.003900593  max resid 0.05271625
# Run 11 stress 0.2044738
# Run 12 stress 0.2044985
# Run 13 stress 0.204132
# Run 14 stress 0.2044985
# Run 15 stress 0.2049987
# Run 16 stress 0.2044985
# Run 17 stress 0.203589
# ... New best solution
# ... Procrustes: rmse 9.422828e-06  max resid 4.131225e-05
# ... Similar to previous best
# Run 18 stress 0.2040316
# ... Procrustes: rmse 0.006935895  max resid 0.02190806
# Run 19 stress 0.2044985
# Run 20 stress 0.2039595
# ... Procrustes: rmse 0.006213719  max resid 0.06014207
# *** Solution reached
# [1] 0.203589
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//goedkoop/goedkoop.models.dist.tsv"
# Run 0 stress 0.2202487
# Run 1 stress 0.2192134
# ... New best solution
# ... Procrustes: rmse 0.02421485  max resid 0.08599635
# Run 2 stress 0.2192133
# ... New best solution
# ... Procrustes: rmse 0.0001473759  max resid 0.0009924527
# ... Similar to previous best
# Run 3 stress 0.2523426
# Run 4 stress 0.2192135
# ... Procrustes: rmse 0.0001783148  max resid 0.001204135
# ... Similar to previous best
# Run 5 stress 0.2192132
# ... New best solution
# ... Procrustes: rmse 1.801673e-05  max resid 6.814652e-05
# ... Similar to previous best
# Run 6 stress 0.2202487
# Run 7 stress 0.2192133
# ... Procrustes: rmse 0.0001121033  max resid 0.0007533019
# ... Similar to previous best
# Run 8 stress 0.2192133
# ... Procrustes: rmse 6.591355e-05  max resid 0.0004000053
# ... Similar to previous best
# Run 9 stress 0.2192132
# ... Procrustes: rmse 3.608803e-05  max resid 0.0002148004
# ... Similar to previous best
# Run 10 stress 0.2202488
# Run 11 stress 0.2192134
# ... Procrustes: rmse 0.0001258267  max resid 0.0008460725
# ... Similar to previous best
# Run 12 stress 0.2192132
# ... New best solution
# ... Procrustes: rmse 9.840686e-06  max resid 5.600363e-05
# ... Similar to previous best
# Run 13 stress 0.2192133
# ... Procrustes: rmse 2.682722e-05  max resid 0.0001465733
# ... Similar to previous best
# Run 14 stress 0.2192132
# ... Procrustes: rmse 1.56538e-05  max resid 8.492688e-05
# ... Similar to previous best
# Run 15 stress 0.2192136
# ... Procrustes: rmse 0.0001706113  max resid 0.001160261
# ... Similar to previous best
# Run 16 stress 0.2192132
# ... Procrustes: rmse 1.124561e-05  max resid 6.938872e-05
# ... Similar to previous best
# Run 17 stress 0.2202488
# Run 18 stress 0.2205197
# Run 19 stress 0.2202487
# Run 20 stress 0.2192132
# ... Procrustes: rmse 1.645629e-05  max resid 0.0001014135
# ... Similar to previous best
# *** Solution reached
# [1] 0.2192132
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//grijs/grijs.models.dist.tsv"
# Run 0 stress 0.1902844
# Run 1 stress 0.1901122
# ... New best solution
# ... Procrustes: rmse 0.01860858  max resid 0.08279699
# Run 2 stress 0.1901113
# ... New best solution
# ... Procrustes: rmse 0.0005922201  max resid 0.006294957
# ... Similar to previous best
# Run 3 stress 0.2136175
# Run 4 stress 0.1906305
# Run 5 stress 0.1902464
# ... Procrustes: rmse 0.02046965  max resid 0.0861701
# Run 6 stress 0.1901122
# ... Procrustes: rmse 0.0005920351  max resid 0.006295112
# ... Similar to previous best
# Run 7 stress 0.1901113
# ... Procrustes: rmse 2.104763e-05  max resid 9.060187e-05
# ... Similar to previous best
# Run 8 stress 0.1901122
# ... Procrustes: rmse 0.0005925173  max resid 0.006294624
# ... Similar to previous best
# Run 9 stress 0.1901113
# ... New best solution
# ... Procrustes: rmse 9.400035e-06  max resid 4.048404e-05
# ... Similar to previous best
# Run 10 stress 0.1902464
# ... Procrustes: rmse 0.02047045  max resid 0.08617796
# Run 11 stress 0.1902464
# ... Procrustes: rmse 0.02046988  max resid 0.0861753
# Run 12 stress 0.1901113
# ... Procrustes: rmse 1.336026e-05  max resid 6.468761e-05
# ... Similar to previous best
# Run 13 stress 0.1901122
# ... Procrustes: rmse 0.0005920864  max resid 0.00629073
# ... Similar to previous best
# Run 14 stress 0.1907137
# Run 15 stress 0.1903354
# ... Procrustes: rmse 0.01833512  max resid 0.08415061
# Run 16 stress 0.1909038
# Run 17 stress 0.1908795
# Run 18 stress 0.1902564
# ... Procrustes: rmse 0.02045722  max resid 0.08618716
# Run 19 stress 0.1902464
# ... Procrustes: rmse 0.02046946  max resid 0.08617718
# Run 20 stress 0.1901113
# ... New best solution
# ... Procrustes: rmse 6.856114e-06  max resid 3.153416e-05
# ... Similar to previous best
# *** Solution reached
# [1] 0.1901113
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//hachelijk/hachelijk.models.dist.tsv"
# Run 0 stress 0.145858
# Run 1 stress 0.1458265
# ... New best solution
# ... Procrustes: rmse 0.005017847  max resid 0.03501905
# Run 2 stress 0.146318
# ... Procrustes: rmse 0.009371074  max resid 0.035395
# Run 3 stress 0.1458267
# ... Procrustes: rmse 9.900211e-05  max resid 0.001293322
# ... Similar to previous best
# Run 4 stress 0.1458581
# ... Procrustes: rmse 0.005014037  max resid 0.03494596
# Run 5 stress 0.145858
# ... Procrustes: rmse 0.005015633  max resid 0.03494492
# Run 6 stress 0.1458266
# ... Procrustes: rmse 3.506894e-05  max resid 0.0004520254
# ... Similar to previous best
# Run 7 stress 0.1463179
# ... Procrustes: rmse 0.00937287  max resid 0.0353971
# Run 8 stress 0.1458188
# ... New best solution
# ... Procrustes: rmse 0.003758978  max resid 0.03437295
# Run 9 stress 0.1463179
# ... Procrustes: rmse 0.007416808  max resid 0.02785145
# Run 10 stress 0.1458265
# ... Procrustes: rmse 0.0037554  max resid 0.03441902
# Run 11 stress 0.1458267
# ... Procrustes: rmse 0.003757862  max resid 0.03447493
# Run 12 stress 0.1458265
# ... Procrustes: rmse 0.003756658  max resid 0.03439812
# Run 13 stress 0.1463179
# ... Procrustes: rmse 0.007426234  max resid 0.02791093
# Run 14 stress 0.1463182
# ... Procrustes: rmse 0.007397021  max resid 0.02766116
# Run 15 stress 0.1463179
# ... Procrustes: rmse 0.007413448  max resid 0.0278253
# Run 16 stress 0.1458579
# ... Procrustes: rmse 0.002595381  max resid 0.02460757
# Run 17 stress 0.1458267
# ... Procrustes: rmse 0.00375725  max resid 0.03448779
# Run 18 stress 0.1463179
# ... Procrustes: rmse 0.007411422  max resid 0.02783419
# Run 19 stress 0.1463179
# ... Procrustes: rmse 0.007421355  max resid 0.02787752
# Run 20 stress 0.1458856
# ... Procrustes: rmse 0.002388688  max resid 0.0316541
# Run 21 stress 0.1458579
# ... Procrustes: rmse 0.00259369  max resid 0.02460993
# Run 22 stress 0.145858
# ... Procrustes: rmse 0.002595803  max resid 0.02459515
# Run 23 stress 0.1458266
# ... Procrustes: rmse 0.003762859  max resid 0.03443533
# Run 24 stress 0.1458581
# ... Procrustes: rmse 0.002607489  max resid 0.02468174
# Run 25 stress 0.1458579
# ... Procrustes: rmse 0.002599257  max resid 0.02463702
# Run 26 stress 0.1458266
# ... Procrustes: rmse 0.003761409  max resid 0.03441897
# Run 27 stress 0.1458266
# ... Procrustes: rmse 0.00375983  max resid 0.0344399
# Run 28 stress 0.1463179
# ... Procrustes: rmse 0.007420656  max resid 0.02783608
# Run 29 stress 0.1463179
# ... Procrustes: rmse 0.007425779  max resid 0.02790683
# Run 30 stress 0.1458581
# ... Procrustes: rmse 0.002571574  max resid 0.02440603
# *** No convergence -- monoMDS stopping criteria:
#     18: stress ratio > sratmax
#     12: scale factor of the gradient < sfgrmin
# [1] 0.1458188
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//haken/haken.models.dist.tsv"
# Run 0 stress 0.1593814
# Run 1 stress 0.1663004
# Run 2 stress 0.1658492
# Run 3 stress 0.1788677
# Run 4 stress 0.1795735
# Run 5 stress 0.1729104
# Run 6 stress 0.1706245
# Run 7 stress 0.1685467
# Run 8 stress 0.1594581
# ... Procrustes: rmse 0.01360349  max resid 0.1016286
# Run 9 stress 0.1591602
# ... New best solution
# ... Procrustes: rmse 0.01046514  max resid 0.1015563
# Run 10 stress 0.1648526
# Run 11 stress 0.1751023
# Run 12 stress 0.1637802
# Run 13 stress 0.1688472
# Run 14 stress 0.160918
# Run 15 stress 0.1729121
# Run 16 stress 0.1727473
# Run 17 stress 0.1949874
# Run 18 stress 0.1794186
# Run 19 stress 0.184782
# Run 20 stress 0.1659046
# Run 21 stress 0.1682086
# Run 22 stress 0.1720426
# Run 23 stress 0.1645912
# Run 24 stress 0.1599611
# Run 25 stress 0.1665043
# Run 26 stress 0.1819811
# Run 27 stress 0.1721307
# Run 28 stress 0.1591625
# ... Procrustes: rmse 0.0002551603  max resid 0.002989074
# ... Similar to previous best
# *** Solution reached
# [1] 0.1591602
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//harden/harden.models.dist.tsv"
# Run 0 stress 0.1741839
# Run 1 stress 0.1743901
# ... Procrustes: rmse 0.007685486  max resid 0.05012463
# Run 2 stress 0.1829253
# Run 3 stress 0.1789969
# Run 4 stress 0.1741836
# ... New best solution
# ... Procrustes: rmse 5.441129e-05  max resid 0.0005753025
# ... Similar to previous best
# Run 5 stress 0.1789969
# Run 6 stress 0.1767771
# Run 7 stress 0.1741644
# ... New best solution
# ... Procrustes: rmse 0.001830833  max resid 0.02370949
# Run 8 stress 0.1775755
# Run 9 stress 0.1767406
# Run 10 stress 0.1767387
# Run 11 stress 0.1789969
# Run 12 stress 0.17439
# ... Procrustes: rmse 0.00704407  max resid 0.0488572
# Run 13 stress 0.1743901
# ... Procrustes: rmse 0.007059653  max resid 0.04890935
# Run 14 stress 0.1767387
# Run 15 stress 0.1741561
# ... New best solution
# ... Procrustes: rmse 0.001228359  max resid 0.01047315
# Run 16 stress 0.1775755
# Run 17 stress 0.1775761
# Run 18 stress 0.1767387
# Run 19 stress 0.1767387
# Run 20 stress 0.174156
# ... New best solution
# ... Procrustes: rmse 4.304075e-05  max resid 0.0004337621
# ... Similar to previous best
# *** Solution reached
# [1] 0.174156
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//haten/haten.models.dist.tsv"
# Run 0 stress 0.1747422
# Run 1 stress 0.1861273
# Run 2 stress 0.1750418
# ... Procrustes: rmse 0.01114137  max resid 0.1024868
# Run 3 stress 0.1866842
# Run 4 stress 0.1858016
# Run 5 stress 0.1745812
# ... New best solution
# ... Procrustes: rmse 0.01788251  max resid 0.1111167
# Run 6 stress 0.1836221
# Run 7 stress 0.2146
# Run 8 stress 0.1950236
# Run 9 stress 0.1927249
# Run 10 stress 0.1928099
# Run 11 stress 0.1745964
# ... Procrustes: rmse 0.001829321  max resid 0.02433311
# Run 12 stress 0.1759618
# Run 13 stress 0.1844712
# Run 14 stress 0.2107824
# Run 15 stress 0.1910573
# Run 16 stress 0.2035853
# Run 17 stress 0.1844742
# Run 18 stress 0.1977746
# Run 19 stress 0.1998173
# Run 20 stress 0.191998
# Run 21 stress 0.1855198
# Run 22 stress 0.1915181
# Run 23 stress 0.1951598
# Run 24 stress 0.1745812
# ... New best solution
# ... Procrustes: rmse 3.039198e-05  max resid 0.0001451961
# ... Similar to previous best
# *** Solution reached
# [1] 0.1745812
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//heet/heet.models.dist.tsv"
# Run 0 stress 0.1633545
# Run 1 stress 0.1610806
# ... New best solution
# ... Procrustes: rmse 0.009597834  max resid 0.07074763
# Run 2 stress 0.1610806
# ... New best solution
# ... Procrustes: rmse 0.0001091328  max resid 0.001142686
# ... Similar to previous best
# Run 3 stress 0.1610806
# ... New best solution
# ... Procrustes: rmse 5.754919e-06  max resid 4.058387e-05
# ... Similar to previous best
# Run 4 stress 0.1610806
# ... Procrustes: rmse 1.489801e-05  max resid 0.0001315015
# ... Similar to previous best
# Run 5 stress 0.1634732
# Run 6 stress 0.1631437
# Run 7 stress 0.1634577
# Run 8 stress 0.1633545
# Run 9 stress 0.1630162
# Run 10 stress 0.1610806
# ... Procrustes: rmse 6.286798e-06  max resid 4.987765e-05
# ... Similar to previous best
# Run 11 stress 0.1610806
# ... Procrustes: rmse 1.468815e-05  max resid 0.0001318615
# ... Similar to previous best
# Run 12 stress 0.1610806
# ... New best solution
# ... Procrustes: rmse 7.188615e-06  max resid 4.166622e-05
# ... Similar to previous best
# Run 13 stress 0.1632829
# Run 14 stress 0.1632427
# Run 15 stress 0.1634156
# Run 16 stress 0.1632427
# Run 17 stress 0.1610805
# ... New best solution
# ... Procrustes: rmse 6.330016e-05  max resid 0.0006812334
# ... Similar to previous best
# Run 18 stress 0.1610806
# ... Procrustes: rmse 7.820367e-05  max resid 0.0008251358
# ... Similar to previous best
# Run 19 stress 0.1634732
# Run 20 stress 0.1610806
# ... Procrustes: rmse 7.759557e-05  max resid 0.0008234727
# ... Similar to previous best
# *** Solution reached
# [1] 0.1610805
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//heffen/heffen.models.dist.tsv"
# Run 0 stress 0.1989011
# Run 1 stress 0.1863499
# ... New best solution
# ... Procrustes: rmse 0.02327379  max resid 0.1492167
# Run 2 stress 0.2270746
# Run 3 stress 0.2135624
# Run 4 stress 0.1863499
# ... New best solution
# ... Procrustes: rmse 1.061713e-05  max resid 9.909482e-05
# ... Similar to previous best
# Run 5 stress 0.1863499
# ... Procrustes: rmse 1.760589e-05  max resid 0.0001370603
# ... Similar to previous best
# Run 6 stress 0.2204363
# Run 7 stress 0.1863499
# ... Procrustes: rmse 1.471387e-05  max resid 0.0001424736
# ... Similar to previous best
# Run 8 stress 0.1863499
# ... Procrustes: rmse 9.870135e-06  max resid 9.198296e-05
# ... Similar to previous best
# Run 9 stress 0.1863499
# ... Procrustes: rmse 2.431374e-05  max resid 0.0001895848
# ... Similar to previous best
# Run 10 stress 0.1863499
# ... New best solution
# ... Procrustes: rmse 1.287405e-05  max resid 0.0001296544
# ... Similar to previous best
# Run 11 stress 0.1863499
# ... Procrustes: rmse 1.019301e-05  max resid 0.0001241892
# ... Similar to previous best
# Run 12 stress 0.2212811
# Run 13 stress 0.1863499
# ... Procrustes: rmse 1.441343e-05  max resid 0.0001224691
# ... Similar to previous best
# Run 14 stress 0.215229
# Run 15 stress 0.1863499
# ... Procrustes: rmse 6.389795e-06  max resid 6.394442e-05
# ... Similar to previous best
# Run 16 stress 0.1863499
# ... Procrustes: rmse 8.571259e-06  max resid 6.224822e-05
# ... Similar to previous best
# Run 17 stress 0.1863499
# ... Procrustes: rmse 9.25615e-06  max resid 8.864693e-05
# ... Similar to previous best
# Run 18 stress 0.2142247
# Run 19 stress 0.2219896
# Run 20 stress 0.1863499
# ... Procrustes: rmse 1.371532e-05  max resid 0.0001400089
# ... Similar to previous best
# *** Solution reached
# [1] 0.1863499
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//heilzaam/heilzaam.models.dist.tsv"
# Run 0 stress 0.1696401
# Run 1 stress 0.1696412
# ... Procrustes: rmse 0.0005392992  max resid 0.003183512
# ... Similar to previous best
# Run 2 stress 0.1696788
# ... Procrustes: rmse 0.004007339  max resid 0.01732166
# Run 3 stress 0.16964
# ... New best solution
# ... Procrustes: rmse 0.0002490793  max resid 0.001209789
# ... Similar to previous best
# Run 4 stress 0.1696735
# ... Procrustes: rmse 0.002799513  max resid 0.01430395
# Run 5 stress 0.1696404
# ... Procrustes: rmse 0.0002997763  max resid 0.001487231
# ... Similar to previous best
# Run 6 stress 0.1696417
# ... Procrustes: rmse 0.000449672  max resid 0.001979437
# ... Similar to previous best
# Run 7 stress 0.1696406
# ... Procrustes: rmse 0.0003357243  max resid 0.001441094
# ... Similar to previous best
# Run 8 stress 0.1696756
# ... Procrustes: rmse 0.003556854  max resid 0.01545117
# Run 9 stress 0.1696404
# ... Procrustes: rmse 0.0001377095  max resid 0.0008328517
# ... Similar to previous best
# Run 10 stress 0.1696405
# ... Procrustes: rmse 0.0003088502  max resid 0.001520843
# ... Similar to previous best
# Run 11 stress 0.1696415
# ... Procrustes: rmse 0.0003391695  max resid 0.00234287
# ... Similar to previous best
# Run 12 stress 0.1696755
# ... Procrustes: rmse 0.003550654  max resid 0.01542921
# Run 13 stress 0.1696758
# ... Procrustes: rmse 0.003601922  max resid 0.01564677
# Run 14 stress 0.1696742
# ... Procrustes: rmse 0.003588169  max resid 0.01564578
# Run 15 stress 0.1696408
# ... Procrustes: rmse 0.0003786307  max resid 0.001619644
# ... Similar to previous best
# Run 16 stress 0.1696431
# ... Procrustes: rmse 0.000544734  max resid 0.004018987
# ... Similar to previous best
# Run 17 stress 0.1696403
# ... Procrustes: rmse 0.0002781489  max resid 0.001263256
# ... Similar to previous best
# Run 18 stress 0.169675
# ... Procrustes: rmse 0.003417694  max resid 0.01481171
# Run 19 stress 0.1696403
# ... Procrustes: rmse 0.0002920394  max resid 0.001456227
# ... Similar to previous best
# Run 20 stress 0.1696752
# ... Procrustes: rmse 0.003506932  max resid 0.01523188
# *** Solution reached
# [1] 0.16964
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//helpen/helpen.models.dist.tsv"
# Run 0 stress 0.1838594
# Run 1 stress 0.1904182
# Run 2 stress 0.1846146
# Run 3 stress 0.2019701
# Run 4 stress 0.1846144
# Run 5 stress 0.1917017
# Run 6 stress 0.183733
# ... New best solution
# ... Procrustes: rmse 0.003440689  max resid 0.04221998
# Run 7 stress 0.1860568
# Run 8 stress 0.22259
# Run 9 stress 0.1912798
# Run 10 stress 0.2081519
# Run 11 stress 0.1839069
# ... Procrustes: rmse 0.006389118  max resid 0.07535378
# Run 12 stress 0.2210741
# Run 13 stress 0.183913
# ... Procrustes: rmse 0.006424996  max resid 0.07513196
# Run 14 stress 0.4166352
# Run 15 stress 0.1904182
# Run 16 stress 0.1916277
# Run 17 stress 0.1841511
# ... Procrustes: rmse 0.009166007  max resid 0.08988088
# Run 18 stress 0.1839069
# ... Procrustes: rmse 0.00638946  max resid 0.07536124
# Run 19 stress 0.1847507
# Run 20 stress 0.1964835
# Run 21 stress 0.1838815
# ... Procrustes: rmse 0.006437214  max resid 0.07575506
# Run 22 stress 0.2115431
# Run 23 stress 0.1969863
# Run 24 stress 0.2035124
# Run 25 stress 0.2241483
# Run 26 stress 0.183733
# ... Procrustes: rmse 6.605486e-06  max resid 5.603678e-05
# ... Similar to previous best
# *** Solution reached
# [1] 0.183733
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//hemels/hemels.models.dist.tsv"
# Run 0 stress 0.1520239
# Run 1 stress 0.152024
# ... Procrustes: rmse 0.0002504441  max resid 0.002223185
# ... Similar to previous best
# Run 2 stress 0.1520242
# ... Procrustes: rmse 0.0002413173  max resid 0.00260256
# ... Similar to previous best
# Run 3 stress 0.1520239
# ... Procrustes: rmse 0.0002454517  max resid 0.002398416
# ... Similar to previous best
# Run 4 stress 0.1520233
# ... New best solution
# ... Procrustes: rmse 0.0001742622  max resid 0.001379302
# ... Similar to previous best
# Run 5 stress 0.1520245
# ... Procrustes: rmse 0.0004151897  max resid 0.003553053
# ... Similar to previous best
# Run 6 stress 0.1520244
# ... Procrustes: rmse 0.0003229005  max resid 0.002363064
# ... Similar to previous best
# Run 7 stress 0.152024
# ... Procrustes: rmse 0.0002998062  max resid 0.002118358
# ... Similar to previous best
# Run 8 stress 0.1520246
# ... Procrustes: rmse 0.0004409343  max resid 0.00383646
# ... Similar to previous best
# Run 9 stress 0.1520232
# ... New best solution
# ... Procrustes: rmse 0.0001229525  max resid 0.001150293
# ... Similar to previous best
# Run 10 stress 0.1520237
# ... Procrustes: rmse 0.0003745346  max resid 0.00408089
# ... Similar to previous best
# Run 11 stress 0.1520237
# ... Procrustes: rmse 0.0003280883  max resid 0.003532609
# ... Similar to previous best
# Run 12 stress 0.1520242
# ... Procrustes: rmse 0.0004524773  max resid 0.003847546
# ... Similar to previous best
# Run 13 stress 0.1520234
# ... Procrustes: rmse 0.0001612737  max resid 0.001421964
# ... Similar to previous best
# Run 14 stress 0.1520237
# ... Procrustes: rmse 0.000247319  max resid 0.002203194
# ... Similar to previous best
# Run 15 stress 0.1520232
# ... New best solution
# ... Procrustes: rmse 3.053567e-05  max resid 0.0003157088
# ... Similar to previous best
# Run 16 stress 0.1520247
# ... Procrustes: rmse 0.0004876969  max resid 0.003586231
# ... Similar to previous best
# Run 17 stress 0.1520237
# ... Procrustes: rmse 0.0002152553  max resid 0.002116649
# ... Similar to previous best
# Run 18 stress 0.1520248
# ... Procrustes: rmse 0.0005225078  max resid 0.003822502
# ... Similar to previous best
# Run 19 stress 0.1520232
# ... Procrustes: rmse 6.805506e-05  max resid 0.0006428761
# ... Similar to previous best
# Run 20 stress 0.1520242
# ... Procrustes: rmse 0.0004091882  max resid 0.003734344
# ... Similar to previous best
# *** Solution reached
# [1] 0.1520232
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//herhalen/herhalen.models.dist.tsv"
# Run 0 stress 0.2166545
# Run 1 stress 0.2180582
# Run 2 stress 0.2125928
# ... New best solution
# ... Procrustes: rmse 0.01584316  max resid 0.1110722
# Run 3 stress 0.2548464
# Run 4 stress 0.2449065
# Run 5 stress 0.210714
# ... New best solution
# ... Procrustes: rmse 0.008034927  max resid 0.1132451
# Run 6 stress 0.2201312
# Run 7 stress 0.2213537
# Run 8 stress 0.2207144
# Run 9 stress 0.2224362
# Run 10 stress 0.2148927
# Run 11 stress 0.2190786
# Run 12 stress 0.2338842
# Run 13 stress 0.2231599
# Run 14 stress 0.2195613
# Run 15 stress 0.2139859
# Run 16 stress 0.2107141
# ... Procrustes: rmse 5.843571e-05  max resid 0.000591833
# ... Similar to previous best
# Run 17 stress 0.2190352
# Run 18 stress 0.2190794
# Run 19 stress 0.2199309
# Run 20 stress 0.2281942
# *** Solution reached
# [1] 0.210714
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//herinneren/herinneren.models.dist.tsv"
# Run 0 stress 0.1510061
# Run 1 stress 0.1731898
# Run 2 stress 0.1897496
# Run 3 stress 0.1510039
# ... New best solution
# ... Procrustes: rmse 0.0007516002  max resid 0.008049745
# ... Similar to previous best
# Run 4 stress 0.202302
# Run 5 stress 0.1741918
# Run 6 stress 0.1980887
# Run 7 stress 0.1603246
# Run 8 stress 0.171401
# Run 9 stress 0.1778926
# Run 10 stress 0.1918518
# Run 11 stress 0.1851106
# Run 12 stress 0.1755396
# Run 13 stress 0.1683834
# Run 14 stress 0.1682556
# Run 15 stress 0.1673588
# Run 16 stress 0.1510058
# ... Procrustes: rmse 0.000325901  max resid 0.002434183
# ... Similar to previous best
# Run 17 stress 0.1775494
# Run 18 stress 0.1683378
# Run 19 stress 0.1603262
# Run 20 stress 0.1734309
# *** Solution reached
# [1] 0.1510039
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//herroepen/herroepen.models.dist.tsv"
# Run 0 stress 0.2155186
# Run 1 stress 0.2155956
# ... Procrustes: rmse 0.02823371  max resid 0.1383907
# Run 2 stress 0.2116764
# ... New best solution
# ... Procrustes: rmse 0.05554879  max resid 0.1686395
# Run 3 stress 0.2238815
# Run 4 stress 0.2261067
# Run 5 stress 0.2270993
# Run 6 stress 0.2283372
# Run 7 stress 0.2116764
# ... New best solution
# ... Procrustes: rmse 4.84733e-06  max resid 4.095248e-05
# ... Similar to previous best
# Run 8 stress 0.3214169
# Run 9 stress 0.2229205
# Run 10 stress 0.221166
# Run 11 stress 0.2214382
# Run 12 stress 0.2241684
# Run 13 stress 0.215785
# Run 14 stress 0.2154441
# Run 15 stress 0.2260524
# Run 16 stress 0.2116764
# ... Procrustes: rmse 1.277337e-05  max resid 8.376382e-05
# ... Similar to previous best
# Run 17 stress 0.2154442
# Run 18 stress 0.228717
# Run 19 stress 0.2154941
# Run 20 stress 0.2116764
# ... Procrustes: rmse 3.441392e-06  max resid 2.637428e-05
# ... Similar to previous best
# *** Solution reached
# [1] 0.2116764
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//herstellen/herstellen.models.dist.tsv"
# Run 0 stress 0.2044447
# Run 1 stress 0.2044593
# ... Procrustes: rmse 0.004297047  max resid 0.02443663
# Run 2 stress 0.2044755
# ... Procrustes: rmse 0.002349336  max resid 0.01761671
# Run 3 stress 0.2044594
# ... Procrustes: rmse 0.004374015  max resid 0.0248292
# Run 4 stress 0.2027686
# ... New best solution
# ... Procrustes: rmse 0.02841403  max resid 0.1257905
# Run 5 stress 0.2027686
# ... New best solution
# ... Procrustes: rmse 9.614249e-06  max resid 6.222584e-05
# ... Similar to previous best
# Run 6 stress 0.204692
# Run 7 stress 0.2027686
# ... Procrustes: rmse 4.838753e-06  max resid 3.361581e-05
# ... Similar to previous best
# Run 8 stress 0.2046879
# Run 9 stress 0.2027686
# ... Procrustes: rmse 1.019578e-05  max resid 0.0001064296
# ... Similar to previous best
# Run 10 stress 0.2046698
# Run 11 stress 0.2027686
# ... Procrustes: rmse 1.174889e-05  max resid 0.0001032166
# ... Similar to previous best
# Run 12 stress 0.2047581
# Run 13 stress 0.2046698
# Run 14 stress 0.2027686
# ... Procrustes: rmse 1.093832e-05  max resid 7.704958e-05
# ... Similar to previous best
# Run 15 stress 0.2044593
# Run 16 stress 0.2319757
# Run 17 stress 0.2045393
# Run 18 stress 0.2044594
# Run 19 stress 0.2044594
# Run 20 stress 0.236941
# *** Solution reached
# [1] 0.2027686
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//herstructureren/herstructureren.models.dist.tsv"
# Run 0 stress 0.1942439
# Run 1 stress 0.1942449
# ... Procrustes: rmse 0.0002476894  max resid 0.002609503
# ... Similar to previous best
# Run 2 stress 0.1942439
# ... New best solution
# ... Procrustes: rmse 2.94292e-05  max resid 0.0003499934
# ... Similar to previous best
# Run 3 stress 0.1987011
# Run 4 stress 0.2196443
# Run 5 stress 0.1942449
# ... Procrustes: rmse 0.000248568  max resid 0.00263
# ... Similar to previous best
# Run 6 stress 0.1942449
# ... Procrustes: rmse 0.0002503204  max resid 0.002618664
# ... Similar to previous best
# Run 7 stress 0.1942449
# ... Procrustes: rmse 0.0002466479  max resid 0.002612045
# ... Similar to previous best
# Run 8 stress 0.1942449
# ... Procrustes: rmse 0.0002492047  max resid 0.002616644
# ... Similar to previous best
# Run 9 stress 0.1942449
# ... Procrustes: rmse 0.0002483945  max resid 0.002628791
# ... Similar to previous best
# Run 10 stress 0.1942449
# ... Procrustes: rmse 0.0002465065  max resid 0.002607186
# ... Similar to previous best
# Run 11 stress 0.1942439
# ... Procrustes: rmse 2.570631e-05  max resid 0.0003003898
# ... Similar to previous best
# Run 12 stress 0.1987011
# Run 13 stress 0.2015324
# Run 14 stress 0.218657
# Run 15 stress 0.2036834
# Run 16 stress 0.1942449
# ... Procrustes: rmse 0.0002476326  max resid 0.002611598
# ... Similar to previous best
# Run 17 stress 0.2128884
# Run 18 stress 0.1942439
# ... Procrustes: rmse 3.709556e-05  max resid 0.0004289821
# ... Similar to previous best
# Run 19 stress 0.1942439
# ... Procrustes: rmse 2.174855e-05  max resid 0.0002318363
# ... Similar to previous best
# Run 20 stress 0.2169316
# *** Solution reached
# [1] 0.1942439
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//hoekig/hoekig.models.dist.tsv"
# Run 0 stress 0.2028071
# Run 1 stress 0.2028071
# ... Procrustes: rmse 7.517764e-06  max resid 3.913019e-05
# ... Similar to previous best
# Run 2 stress 0.2027351
# ... New best solution
# ... Procrustes: rmse 0.002138973  max resid 0.02013121
# Run 3 stress 0.2028071
# ... Procrustes: rmse 0.002150246  max resid 0.02021169
# Run 4 stress 0.2027342
# ... New best solution
# ... Procrustes: rmse 0.0001551195  max resid 0.001728715
# ... Similar to previous best
# Run 5 stress 0.2027343
# ... Procrustes: rmse 3.948184e-05  max resid 0.000287683
# ... Similar to previous best
# Run 6 stress 0.2027342
# ... Procrustes: rmse 8.885223e-06  max resid 4.253349e-05
# ... Similar to previous best
# Run 7 stress 0.202807
# ... Procrustes: rmse 0.002117839  max resid 0.01999296
# Run 8 stress 0.202807
# ... Procrustes: rmse 0.002143429  max resid 0.02009866
# Run 9 stress 0.2027342
# ... New best solution
# ... Procrustes: rmse 4.065445e-05  max resid 0.0002878327
# ... Similar to previous best
# Run 10 stress 0.202807
# ... Procrustes: rmse 0.002147593  max resid 0.02006718
# Run 11 stress 0.2027343
# ... Procrustes: rmse 5.633897e-05  max resid 0.0002877852
# ... Similar to previous best
# Run 12 stress 0.2028071
# ... Procrustes: rmse 0.002186756  max resid 0.0203076
# Run 13 stress 0.202807
# ... Procrustes: rmse 0.002161837  max resid 0.02015829
# Run 14 stress 0.202807
# ... Procrustes: rmse 0.00215364  max resid 0.0201197
# Run 15 stress 0.2027342
# ... Procrustes: rmse 4.486369e-05  max resid 0.0002875588
# ... Similar to previous best
# Run 16 stress 0.2285665
# Run 17 stress 0.2027343
# ... Procrustes: rmse 5.674375e-05  max resid 0.0002877603
# ... Similar to previous best
# Run 18 stress 0.202807
# ... Procrustes: rmse 0.002127517  max resid 0.01997501
# Run 19 stress 0.2027351
# ... Procrustes: rmse 0.0001736912  max resid 0.001936688
# ... Similar to previous best
# Run 20 stress 0.2028071
# ... Procrustes: rmse 0.002165354  max resid 0.02018134
# *** Solution reached
# [1] 0.2027342
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//hoop/hoop.models.dist.tsv"
# Run 0 stress 0.1620196
# Run 1 stress 0.1638159
# Run 2 stress 0.1620196
# ... New best solution
# ... Procrustes: rmse 5.23732e-05  max resid 0.0004651869
# ... Similar to previous best
# Run 3 stress 0.1632183
# Run 4 stress 0.1964613
# Run 5 stress 0.1889613
# Run 6 stress 0.1971548
# Run 7 stress 0.1814939
# Run 8 stress 0.2027364
# Run 9 stress 0.1744431
# Run 10 stress 0.2068328
# Run 11 stress 0.1844664
# Run 12 stress 0.199696
# Run 13 stress 0.1974675
# Run 14 stress 0.2112857
# Run 15 stress 0.1901139
# Run 16 stress 0.185264
# Run 17 stress 0.1923456
# Run 18 stress 0.2011876
# Run 19 stress 0.2000742
# Run 20 stress 0.1743904
# *** Solution reached
# [1] 0.1620196
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//hoopvol/hoopvol.models.dist.tsv"
# Run 0 stress 0.204805
# Run 1 stress 0.204805
# ... Procrustes: rmse 2.250562e-05  max resid 0.0001236497
# ... Similar to previous best
# Run 2 stress 0.2048059
# ... Procrustes: rmse 0.0003040809  max resid 0.003809428
# ... Similar to previous best
# Run 3 stress 0.204806
# ... Procrustes: rmse 0.0004197261  max resid 0.004053389
# ... Similar to previous best
# Run 4 stress 0.204806
# ... Procrustes: rmse 0.0004216173  max resid 0.004061694
# ... Similar to previous best
# Run 5 stress 0.204805
# ... Procrustes: rmse 6.500503e-06  max resid 5.891592e-05
# ... Similar to previous best
# Run 6 stress 0.204806
# ... Procrustes: rmse 0.0004210318  max resid 0.004060349
# ... Similar to previous best
# Run 7 stress 0.204805
# ... Procrustes: rmse 1.813843e-05  max resid 0.000132536
# ... Similar to previous best
# Run 8 stress 0.204806
# ... Procrustes: rmse 0.0004247494  max resid 0.004079524
# ... Similar to previous best
# Run 9 stress 0.204806
# ... Procrustes: rmse 0.00041956  max resid 0.004054196
# ... Similar to previous best
# Run 10 stress 0.204805
# ... Procrustes: rmse 1.888384e-05  max resid 0.0001191102
# ... Similar to previous best
# Run 11 stress 0.204805
# ... New best solution
# ... Procrustes: rmse 8.526052e-06  max resid 6.45867e-05
# ... Similar to previous best
# Run 12 stress 0.204805
# ... Procrustes: rmse 1.391033e-05  max resid 9.874943e-05
# ... Similar to previous best
# Run 13 stress 0.204806
# ... Procrustes: rmse 0.0004179622  max resid 0.004024339
# ... Similar to previous best
# Run 14 stress 0.2048059
# ... Procrustes: rmse 0.000298378  max resid 0.003750387
# ... Similar to previous best
# Run 15 stress 0.204806
# ... Procrustes: rmse 0.0004050747  max resid 0.003961397
# ... Similar to previous best
# Run 16 stress 0.204805
# ... Procrustes: rmse 1.673895e-05  max resid 0.0001064119
# ... Similar to previous best
# Run 17 stress 0.204805
# ... Procrustes: rmse 9.911203e-06  max resid 7.370638e-05
# ... Similar to previous best
# Run 18 stress 0.204806
# ... Procrustes: rmse 0.0004111746  max resid 0.003967169
# ... Similar to previous best
# Run 19 stress 0.204806
# ... Procrustes: rmse 0.0004194593  max resid 0.004034526
# ... Similar to previous best
# Run 20 stress 0.204805
# ... Procrustes: rmse 2.215251e-05  max resid 0.000141247
# ... Similar to previous best
# *** Solution reached
# [1] 0.204805
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//horde/horde.models.dist.tsv"
# Run 0 stress 0.1592242
# Run 1 stress 0.1599913
# Run 2 stress 0.2223971
# Run 3 stress 0.2009437
# Run 4 stress 0.1953126
# Run 5 stress 0.1722076
# Run 6 stress 0.1681331
# Run 7 stress 0.2361194
# Run 8 stress 0.1589016
# ... New best solution
# ... Procrustes: rmse 0.007738845  max resid 0.06827277
# Run 9 stress 0.1882058
# Run 10 stress 0.1590497
# ... Procrustes: rmse 0.006507705  max resid 0.0673761
# Run 11 stress 0.1683787
# Run 12 stress 0.1741161
# Run 13 stress 0.1825332
# Run 14 stress 0.1770824
# Run 15 stress 0.168133
# Run 16 stress 0.1590446
# ... Procrustes: rmse 0.006401735  max resid 0.06731513
# Run 17 stress 0.1851303
# Run 18 stress 0.1589017
# ... Procrustes: rmse 4.391043e-05  max resid 0.0003294635
# ... Similar to previous best
# Run 19 stress 0.1923016
# Run 20 stress 0.2356402
# *** Solution reached
# [1] 0.1589016
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//huldigen/huldigen.models.dist.tsv"
# Run 0 stress 0.2309522
# Run 1 stress 0.236736
# Run 2 stress 0.2763086
# Run 3 stress 0.2453178
# Run 4 stress 0.2438621
# Run 5 stress 0.2360721
# Run 6 stress 0.2311927
# ... Procrustes: rmse 0.01156822  max resid 0.06830463
# Run 7 stress 0.2604003
# Run 8 stress 0.2690216
# Run 9 stress 0.2341484
# Run 10 stress 0.247609
# Run 11 stress 0.2366212
# Run 12 stress 0.2360969
# Run 13 stress 0.2362418
# Run 14 stress 0.2376604
# Run 15 stress 0.2442415
# Run 16 stress 0.239358
# Run 17 stress 0.2324045
# Run 18 stress 0.2858931
# Run 19 stress 0.4165035
# Run 20 stress 0.2421394
# Run 21 stress 0.2267797
# ... New best solution
# ... Procrustes: rmse 0.02095414  max resid 0.1046101
# Run 22 stress 0.2453833
# Run 23 stress 0.2382999
# Run 24 stress 0.2290175
# Run 25 stress 0.2438742
# Run 26 stress 0.2397727
# Run 27 stress 0.2592404
# Run 28 stress 0.2494357
# Run 29 stress 0.2396155
# Run 30 stress 0.2589621
# *** No convergence -- monoMDS stopping criteria:
#      1: no. of iterations >= maxit
#     22: stress ratio > sratmax
#      7: scale factor of the gradient < sfgrmin
# [1] 0.2267797
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//schaal/schaal.models.dist.tsv"
# Run 0 stress 0.1567547
# Run 1 stress 0.1567542
# ... New best solution
# ... Procrustes: rmse 0.0002099932  max resid 0.002678056
# ... Similar to previous best
# Run 2 stress 0.1567541
# ... New best solution
# ... Procrustes: rmse 1.802714e-05  max resid 0.0002251526
# ... Similar to previous best
# Run 3 stress 0.1948501
# Run 4 stress 0.1567547
# ... Procrustes: rmse 0.0002069553  max resid 0.002621691
# ... Similar to previous best
# Run 5 stress 0.1567547
# ... Procrustes: rmse 0.0002070707  max resid 0.002608998
# ... Similar to previous best
# Run 6 stress 0.1567547
# ... Procrustes: rmse 0.0002065935  max resid 0.002616405
# ... Similar to previous best
# Run 7 stress 0.1567541
# ... New best solution
# ... Procrustes: rmse 1.831693e-05  max resid 0.0002104294
# ... Similar to previous best
# Run 8 stress 0.1567547
# ... Procrustes: rmse 0.0002046403  max resid 0.002603079
# ... Similar to previous best
# Run 9 stress 0.1567547
# ... Procrustes: rmse 0.0002152882  max resid 0.002743724
# ... Similar to previous best
# Run 10 stress 0.1567542
# ... Procrustes: rmse 9.095372e-06  max resid 0.0001065955
# ... Similar to previous best
# Run 11 stress 0.1567547
# ... Procrustes: rmse 0.0002080802  max resid 0.002639983
# ... Similar to previous best
# Run 12 stress 0.1567541
# ... New best solution
# ... Procrustes: rmse 9.852659e-06  max resid 0.0001162408
# ... Similar to previous best
# Run 13 stress 0.1567541
# ... Procrustes: rmse 5.888477e-06  max resid 6.084788e-05
# ... Similar to previous best
# Run 14 stress 0.1567541
# ... Procrustes: rmse 6.46235e-06  max resid 7.232806e-05
# ... Similar to previous best
# Run 15 stress 0.1567547
# ... Procrustes: rmse 0.0002086472  max resid 0.002659219
# ... Similar to previous best
# Run 16 stress 0.1567547
# ... Procrustes: rmse 0.0002145458  max resid 0.002730152
# ... Similar to previous best
# Run 17 stress 0.1567547
# ... Procrustes: rmse 0.0002038699  max resid 0.002589256
# ... Similar to previous best
# Run 18 stress 0.1567541
# ... Procrustes: rmse 5.535211e-06  max resid 6.282528e-05
# ... Similar to previous best
# Run 19 stress 0.1567547
# ... Procrustes: rmse 0.000217597  max resid 0.002782864
# ... Similar to previous best
# Run 20 stress 0.1567541
# ... Procrustes: rmse 9.552287e-06  max resid 6.490588e-05
# ... Similar to previous best
# *** Solution reached
# [1] 0.1567541
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//spot/spot.models.dist.tsv"
# Run 0 stress 0.1488642
# Run 1 stress 0.1593896
# Run 2 stress 0.1488643
# ... Procrustes: rmse 1.087515e-05  max resid 0.0001139329
# ... Similar to previous best
# Run 3 stress 0.1488642
# ... Procrustes: rmse 6.430397e-06  max resid 5.623357e-05
# ... Similar to previous best
# Run 4 stress 0.1488642
# ... Procrustes: rmse 2.776644e-06  max resid 2.770191e-05
# ... Similar to previous best
# Run 5 stress 0.1682279
# Run 6 stress 0.1593069
# Run 7 stress 0.1593895
# Run 8 stress 0.1593054
# Run 9 stress 0.1593057
# Run 10 stress 0.1593054
# Run 11 stress 0.1488642
# ... New best solution
# ... Procrustes: rmse 1.873452e-05  max resid 0.0002037157
# ... Similar to previous best
# Run 12 stress 0.1593895
# Run 13 stress 0.1488642
# ... Procrustes: rmse 8.27955e-06  max resid 7.537974e-05
# ... Similar to previous best
# Run 14 stress 0.1488642
# ... Procrustes: rmse 9.561981e-06  max resid 0.0001024116
# ... Similar to previous best
# Run 15 stress 0.1488642
# ... Procrustes: rmse 1.183756e-05  max resid 0.0001597431
# ... Similar to previous best
# Run 16 stress 0.1488642
# ... Procrustes: rmse 1.628528e-05  max resid 0.0001778797
# ... Similar to previous best
# Run 17 stress 0.1488642
# ... Procrustes: rmse 1.469861e-05  max resid 0.000160702
# ... Similar to previous best
# Run 18 stress 0.1488642
# ... Procrustes: rmse 3.6176e-06  max resid 2.534269e-05
# ... Similar to previous best
# Run 19 stress 0.1488642
# ... Procrustes: rmse 1.232663e-05  max resid 8.848092e-05
# ... Similar to previous best
# Run 20 stress 0.1488642
# ... Procrustes: rmse 1.787058e-05  max resid 0.0001660252
# ... Similar to previous best
# *** Solution reached
# [1] 0.1488642
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//staal/staal.models.dist.tsv"
# Run 0 stress 0.1581572
# Run 1 stress 0.1581584
# ... Procrustes: rmse 0.0002089987  max resid 0.002289847
# ... Similar to previous best
# Run 2 stress 0.15817
# ... Procrustes: rmse 0.001293875  max resid 0.01825624
# Run 3 stress 0.1581584
# ... Procrustes: rmse 0.0002053552  max resid 0.002248731
# ... Similar to previous best
# Run 4 stress 0.15817
# ... Procrustes: rmse 0.001297731  max resid 0.01831339
# Run 5 stress 0.416937
# Run 6 stress 0.1582095
# ... Procrustes: rmse 0.002012902  max resid 0.01956536
# Run 7 stress 0.15817
# ... Procrustes: rmse 0.001293869  max resid 0.01825565
# Run 8 stress 0.2136361
# Run 9 stress 0.15817
# ... Procrustes: rmse 0.00129455  max resid 0.01826132
# Run 10 stress 0.1582095
# ... Procrustes: rmse 0.002010798  max resid 0.01954149
# Run 11 stress 0.1581572
# ... New best solution
# ... Procrustes: rmse 8.10781e-06  max resid 8.745461e-05
# ... Similar to previous best
# Run 12 stress 0.1581584
# ... Procrustes: rmse 0.0001945905  max resid 0.00214077
# ... Similar to previous best
# Run 13 stress 0.1581572
# ... New best solution
# ... Procrustes: rmse 3.377102e-05  max resid 0.000352529
# ... Similar to previous best
# Run 14 stress 0.1695769
# Run 15 stress 0.1582095
# ... Procrustes: rmse 0.002041565  max resid 0.01984605
# Run 16 stress 0.15817
# ... Procrustes: rmse 0.001326435  max resid 0.01869477
# Run 17 stress 0.1582095
# ... Procrustes: rmse 0.002046302  max resid 0.01990199
# Run 18 stress 0.1582095
# ... Procrustes: rmse 0.002041513  max resid 0.01984517
# Run 19 stress 0.1800171
# Run 20 stress 0.15817
# ... Procrustes: rmse 0.001327365  max resid 0.01871105
# *** Solution reached
# [1] 0.1581572
# [1] "Models saved"
#   |======================================================================| 100%
# [1] "Matrix created."
# [1] "Distance matrix saved in ../github//stof/stof.models.dist.tsv"
# Run 0 stress 0.1477963
# Run 1 stress 0.1477963
# ... New best solution
# ... Procrustes: rmse 8.420082e-06  max resid 0.0001186426
# ... Similar to previous best
# Run 2 stress 0.1477963
# ... Procrustes: rmse 1.00074e-05  max resid 9.273293e-05
# ... Similar to previous best
# Run 3 stress 0.1477963
# ... Procrustes: rmse 1.189366e-05  max resid 0.0001599
# ... Similar to previous best
# Run 4 stress 0.4167887
# Run 5 stress 0.1477963
# ... New best solution
# ... Procrustes: rmse 1.044251e-05  max resid 0.0001438961
# ... Similar to previous best
# Run 6 stress 0.1477963
# ... New best solution
# ... Procrustes: rmse 1.010203e-05  max resid 0.0001360753
# ... Similar to previous best
# Run 7 stress 0.1636694
# Run 8 stress 0.1477963
# ... Procrustes: rmse 7.137159e-06  max resid 8.392377e-05
# ... Similar to previous best
# Run 9 stress 0.1477963
# ... Procrustes: rmse 7.053959e-06  max resid 3.623968e-05
# ... Similar to previous best
# Run 10 stress 0.1477963
# ... Procrustes: rmse 7.757899e-06  max resid 5.582329e-05
# ... Similar to previous best
# Run 11 stress 0.1477963
# ... Procrustes: rmse 6.607962e-06  max resid 8.027675e-05
# ... Similar to previous best
# Run 12 stress 0.1477963
# ... Procrustes: rmse 1.117516e-05  max resid 7.52128e-05
# ... Similar to previous best
# Run 13 stress 0.1477963
# ... Procrustes: rmse 8.388942e-06  max resid 0.0001000424
# ... Similar to previous best
# Run 14 stress 0.1477963
# ... New best solution
# ... Procrustes: rmse 6.003236e-06  max resid 6.556798e-05
# ... Similar to previous best
# Run 15 stress 0.1477963
# ... New best solution
# ... Procrustes: rmse 1.828702e-06  max resid 9.697174e-06
# ... Similar to previous best
# Run 16 stress 0.1477963
# ... Procrustes: rmse 6.08017e-06  max resid 3.263214e-05
# ... Similar to previous best
# Run 17 stress 0.1477963
# ... Procrustes: rmse 4.915714e-06  max resid 5.047706e-05
# ... Similar to previous best
# Run 18 stress 0.1477963
# ... Procrustes: rmse 6.322019e-06  max resid 3.156894e-05
# ... Similar to previous best
# Run 19 stress 0.1477963
# ... Procrustes: rmse 7.99682e-06  max resid 9.179075e-05
# ... Similar to previous best
# Run 20 stress 0.1477963
# ... New best solution
# ... Procrustes: rmse 3.623936e-06  max resid 1.809827e-05
# ... Similar to previous best
# *** Solution reached
# [1] 0.1477963
# [1] "Models saved"

# %% [markdown]
# ## Medoids
#
# The medoids are simply calculated with `cluster::pam` and some basic information is stored in a `[lemma].medoids.tsv` file. The only important column for the visualization is `medoids`.

# %%
for (lemma in lemmas) {
    distmtx <- read_tsv(file.path(output_dir, lemma, paste0(lemma, ".models.dist.tsv")),
        col_types = cols()) %>% 
    matricizeCloud() %>% as.dist
    pam_data <- cluster::pam(distmtx, k = 8)
    medoid_data <- pam_data$clusinfo %>% as_tibble() %>% mutate(medoids = pam_data$medoids, medoid_i = seq(8))
    write_tsv(medoid_data, file.path(output_dir, lemma, paste0(lemma, ".medoids.tsv")))
    models_file <- file.path(output_dir, lemma, paste0(lemma, ".models.tsv"))
    read_tsv(models_file, show_col_types = FALSE, lazy = FALSE) %>% 
        mutate(
            pam_cluster = pam_data$clustering[`_model`], # add pam-cluster number
            medoid = pam_data$medoids[pam_cluster] # add name of medoid
        ) %>% 
        write_tsv(models_file)
}

# %% [markdown]
# ## HDBSCAN
#
# I've mostly computed HDBSCAN among the medoids, but it could certainly be computed for all models. HDBSCAN information, from clustering to membership probabilities or eps, *could* in principle be included for NephoVis, but I haven't done it because the result varies per model, meaning that each token will have about 200 columns for each of them (or 8 if it's only with the medoids, which it's still a lot), and that is hard to incorporate into the tool.
#
# Instead, I work with an RDS file with a list of models per lemma, and each model object includes:
#
# - coordinates: the coordinates from t-SNE with perplexity 30, next to other variables in the "variables" dataframe like, in my case, "senses", as well as the tailored list of context words. We add the token-wise HDBSCAN info here
# - cws: distribution of first-order context words across HDBSCAN clusters and their t-SNE coordinates if available
# - (optionally) the normal HDBSCAN plot

# %% [markdown]
# I've typically stored this data somewhere else, not really on the visualization GitHub, but it could totally go there. It is more useful for the ShinyApp though.
#
# **Note**
# The ShinyApp currently assumes that this file has a "cw_coords" elements with the coordinates for the context words; it needs to be updated.

# %%
map(setNames(lemmas, lemmas), function(lemma){
    models <- read_tsv(file.path(output_dir, lemma, paste0(lemma, ".medoids.tsv")), show_col_types = FALSE)$medoids
    map(setNames(models, models),
           summarizeHDBSCAN, lemma = lemma,
           input_dir = file.path(input_dir, lemma),
           output_dir = file.path(output_dir, lemma))
}) %>% 
write_rds(file.path(output_dir, "mariana_hdbscan_new.rds"))

# %% [markdown]
# ### What to do with HDBSCAN
#
# Here I will add the code to classify the clouds in types, but later.

# %% [markdown]
# ## Final steps
#
# For the visualization tool, we need to add a file that lists all the files in the directory of a lemma, to help it manage the available data.

# %%
library(stringr)
library(readr)
library(purrr)
library(rjson)
cleanFname <- function(str){
    sections <- str_split(str, "\\.")[[1]]
    paste(sections[-c(1, length(sections))], collapse = "")
}

# %%
for (lemma in lemmas){
    files_list <- setdiff(dir(file.path(output_dir, lemma)), "paths.json")
    names(files_list) <- map_chr(files_list, cleanFname)
    write(toJSON(files_list), file.path(output_dir, lemma, "paths.json"))
}
